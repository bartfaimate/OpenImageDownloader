# %%
import requests
import json
import argparse
import time
import os
import sys

# %%
CLASSES = [
    "Accordion", "Adhesive tape", "Aircraft", "Airplane", "Alarm clock", "Alpaca", "Ambulance", "Animal", "Ant", "Antelope", "Apple", "Armadillo", "Artichoke", "Auto part", "Axe", "Backpack", "Bagel", "Baked goods", "Balance beam", "Ball", "Balloon", "Banana", "Band-aid", "Banjo", "Barge", "Barrel", "Baseball bat", "Baseball glove", "Bat (Animal)", "Bathroom accessory", "Bathroom cabinet", "Bathtub", "Beaker", "Bear", "Bed", "Bee", "Beehive", "Beer", "Beetle", "Bell pepper", "Belt", "Bench", "Bicycle", "Bicycle helmet", "Bicycle wheel", "Bidet", "Billboard", "Billiard table", "Binoculars", "Bird", "Blender", "Blue jay", "Boat", "Bomb", "Book", "Bookcase", "Boot", "Bottle", "Bottle opener", "Bow and arrow", "Bowl", "Bowling equipment", "Box", "Boy", "Brassiere", "Bread", "Briefcase", "Broccoli", "Bronze sculpture", "Brown bear", "Building", "Bull", "Burrito", "Bus", "Bust", "Butterfly", "Cabbage", "Cabinetry", "Cake", "Cake stand", "Calculator", "Camel", "Camera", "Can opener", "Canary", "Candle", "Candy", "Cannon", "Canoe", "Cantaloupe", "Car", "Carnivore", "Carrot", "Cart", "Cassette deck", "Castle", "Cat", "Cat furniture", "Caterpillar", "Cattle", "Ceiling fan", "Cello", "Centipede", "Chainsaw", "Chair", "Cheese", "Cheetah", "Chest of drawers", "Chicken", "Chime", "Chisel", "Chopsticks", "Christmas tree", "Clock", "Closet", "Clothing", "Coat", "Cocktail", "Cocktail shaker", "Coconut", "Coffee", "Coffee cup", "Coffee table", "Coffeemaker", "Coin", "Common fig", "Common sunflower", "Computer keyboard", "Computer monitor", "Computer mouse", "Container", "Convenience store", "Cookie", "Cooking spray", "Corded phone", "Cosmetics", "Couch", "Countertop", "Cowboy hat", "Crab", "Cream", "Cricket ball", "Crocodile", "Croissant", "Crown", "Crutch", "Cucumber", "Cupboard", "Curtain", "Cutting board", "Dagger", "Dairy Product", "Deer", "Desk", "Dessert", "Diaper", "Dice", "Digital clock", "Dinosaur", "Dishwasher", "Dog", "Dog bed", "Doll", "Dolphin", "Door", "Door handle", "Doughnut", "Dragonfly", "Drawer", "Dress", "Drill (Tool)", "Drink", "Drinking straw", "Drum", "Duck", "Dumbbell", "Eagle", "Earrings", "Egg (Food)", "Elephant", "Envelope", "Eraser", "Face powder", "Facial tissue holder", "Falcon", "Fashion accessory", "Fast food", "Fax", "Fedora", "Filing cabinet", "Fire hydrant", "Fireplace", "Fish", "Flag", "Flashlight", "Flower", "Flowerpot", "Flute", "Flying disc", "Food", "Food processor", "Football", "Football helmet", "Footwear", "Fork", "Fountain", "Fox", "French fries", "French horn", "Frog", "Fruit", "Frying pan", "Furniture", "Garden Asparagus", "Gas stove", "Giraffe", "Girl", "Glasses", "Glove", "Goat", "Goggles", "Goldfish", "Golf ball", "Golf cart", "Gondola", "Goose", "Grape", "Grapefruit", "Grinder", "Guacamole", "Guitar", "Hair dryer", "Hair spray", "Hamburger", "Hammer", "Hamster", "Hand dryer", "Handbag", "Handgun", "Harbor seal", "Harmonica", "Harp", "Harpsichord", "Hat", "Headphones", "Heater", "Hedgehog", "Helicopter", "Helmet", "High heels", "Hiking equipment", "Hippopotamus", "Home appliance", "Honeycomb", "Horizontal bar", "Horse", "Hot dog", "House", "Houseplant", "Human arm", "Human beard", "Human body", "Human ear", "Human eye", "Human face", "Human foot", "Human hair", "Human hand", "Human head", "Human leg", "Human mouth", "Human nose", "Humidifier", "Ice cream", "Indoor rower", "Infant bed", "Insect", "Invertebrate", "Ipod", "Isopod", "Jacket", "Jacuzzi", "Jaguar (Animal)", "Jeans", "Jellyfish", "Jet ski", "Jug", "Juice", "Kangaroo", "Kettle", "Kitchen & dining room table", "Kitchen appliance", "Kitchen knife", "Kitchen utensil", "Kitchenware", "Kite", "Knife", "Koala", "Ladder", "Ladle", "Ladybug", "Lamp", "Land vehicle", "Lantern", "Laptop", "Lavender (Plant)", "Lemon", "Leopard", "Light bulb", "Light switch", "Lighthouse", "Lily", "Limousine", "Lion", "Lipstick", "Lizard", "Lobster", "Loveseat", "Luggage and bags", "Lynx", "Magpie", "Mammal", "Man", "Mango", "Maple", "Maracas", "Marine invertebrates", "Marine mammal", "Measuring cup", "Mechanical fan", "Medical equipment", "Microphone", "Microwave oven", "Milk", "Miniskirt", "Mirror", "Missile", "Mixer", "Mixing bowl", "Mobile phone", "Monkey", "Moths and butterflies", "Motorcycle", "Mouse", "Muffin", "Mug", "Mule", "Mushroom", "Musical instrument", "Musical keyboard", "Nail (Construction)", "Necklace", "Nightstand", "Oboe", "Office building", "Office supplies", "Orange", "Organ (Musical Instrument)", "Ostrich", "Otter", "Oven", "Owl", "Oyster", "Paddle", "Palm tree", "Pancake", "Panda", "Paper cutter", "Paper towel", "Parachute", "Parking meter", "Parrot", "Pasta", "Pastry", "Peach", "Pear", "Pen", "Pencil case", "Pencil sharpener", "Penguin", "Perfume", "Person", "Personal care", "Personal flotation device", "Piano", "Picnic basket", "Picture frame", "Pig", "Pillow", "Pineapple", "Pitcher (Container)", "Pizza", "Pizza cutter", "Plant", "Plastic bag", "Plate", "Platter", "Plumbing fixture", "Polar bear", "Pomegranate", "Popcorn", "Porch", "Porcupine", "Poster", "Potato", "Power plugs and sockets", "Pressure cooker", "Pretzel", "Printer", "Pumpkin", "Punching bag", "Rabbit", "Raccoon", "Racket", "Radish", "Ratchet (Device)", "Raven", "Rays and skates", "Red panda", "Refrigerator", "Remote control", "Reptile", "Rhinoceros", "Rifle", "Ring binder", "Rocket", "Roller skates", "Rose", "Rugby ball", "Ruler", "Salad", "Salt and pepper shakers", "Sandal", "Sandwich", "Saucer", "Saxophone", "Scale", "Scarf", "Scissors", "Scoreboard", "Scorpion", "Screwdriver", "Sculpture", "Sea lion", "Sea turtle", "Seafood", "Seahorse", "Seat belt", "Segway", "Serving tray", "Sewing machine", "Shark", "Sheep", "Shelf", "Shellfish", "Shirt", "Shorts", "Shotgun", "Shower", "Shrimp", "Sink", "Skateboard", "Ski", "Skirt", "Skull", "Skunk", "Skyscraper", "Slow cooker", "Snack", "Snail", "Snake", "Snowboard", "Snowman", "Snowmobile", "Snowplow", "Soap dispenser", "Sock", "Sofa bed", "Sombrero", "Sparrow", "Spatula", "Spice rack", "Spider", "Spoon", "Sports equipment", "Sports uniform", "Squash (Plant)", "Squid", "Squirrel", "Stairs", "Stapler", "Starfish", "Stationary bicycle", "Stethoscope", "Stool", "Stop sign", "Strawberry", "Street light", "Stretcher", "Studio couch", "Submarine", "Submarine sandwich", "Suit", "Suitcase", "Sun hat", "Sunglasses", "Surfboard", "Sushi", "Swan", "Swim cap", "Swimming pool", "Swimwear", "Sword", "Syringe", "Table", "Table tennis racket", "Tablet computer", "Tableware", "Taco", "Tank", "Tap", "Tart", "Taxi", "Tea", "Teapot", "Teddy bear", "Telephone", "Television", "Tennis ball", "Tennis racket", "Tent", "Tiara", "Tick", "Tie", "Tiger", "Tin can", "Tire", "Toaster", "Toilet", "Toilet paper", "Tomato", "Tool", "Toothbrush", "Torch", "Tortoise", "Towel", "Tower", "Toy", "Traffic light", "Traffic sign", "Train", "Training bench", "Treadmill", "Tree", "Tree house", "Tripod", "Trombone", "Trousers", "Truck", "Trumpet", "Turkey", "Turtle", "Umbrella", "Unicycle", "Van", "Vase", "Vegetable", "Vehicle", "Vehicle registration plate", "Violin", "Volleyball (Ball)", "Waffle", "Waffle iron", "Wall clock", "Wardrobe", "Washing machine", "Waste container", "Watch", "Watercraft", "Watermelon", "Weapon", "Whale", "Wheel", "Wheelchair", "Whisk", "Whiteboard", "Willow", "Window", "Window blind", "Wine", "Wine glass", "Wine rack", "Winter melon", "Wok", "Woman", "Wood-burning stove", "Woodpecker", "Worm", "Wrench", "Zebra", "Zucchini",
]

# %%
def print_classes(classes):
    for i, c in enumerate(classes):
        print(f"{c:30}", end="")
        if i % 3 == 0:
            print()

def info(msg):
    print("[INFO] " + msg)

# %%
print_classes(CLASSES)
# Out:
# Accordion
# Adhesive tape                 Aircraft                      Airplane
# Alarm clock                   Alpaca                        Ambulance
# Animal                        Ant                           Antelope
# Apple                         Armadillo                     Artichoke
# Auto part                     Axe                           Backpack
# Bagel                         Baked goods                   Balance beam
# Ball                          Balloon                       Banana
# Band-aid                      Banjo                         Barge
# Barrel                        Baseball bat                  Baseball glove
# Bat (Animal)                  Bathroom accessory            Bathroom cabinet
# Bathtub                       Beaker                        Bear
# Bed                           Bee                           Beehive
# Beer                          Beetle                        Bell pepper
# Belt                          Bench                         Bicycle
# Bicycle helmet                Bicycle wheel                 Bidet
# Billboard                     Billiard table                Binoculars
# Bird                          Blender                       Blue jay
# Boat                          Bomb                          Book
# Bookcase                      Boot                          Bottle
# Bottle opener                 Bow and arrow                 Bowl
# Bowling equipment             Box                           Boy
# Brassiere                     Bread                         Briefcase
# Broccoli                      Bronze sculpture              Brown bear
# Building                      Bull                          Burrito
# Bus                           Bust                          Butterfly
# Cabbage                       Cabinetry                     Cake
# Cake stand                    Calculator                    Camel
# Camera                        Can opener                    Canary
# Candle                        Candy                         Cannon
# Canoe                         Cantaloupe                    Car
# Carnivore                     Carrot                        Cart
# Cassette deck                 Castle                        Cat
# Cat furniture                 Caterpillar                   Cattle
# Ceiling fan                   Cello                         Centipede
# Chainsaw                      Chair                         Cheese
# Cheetah                       Chest of drawers              Chicken
# Chime                         Chisel                        Chopsticks
# Christmas tree                Clock                         Closet
# Clothing                      Coat                          Cocktail
# Cocktail shaker               Coconut                       Coffee
# Coffee cup                    Coffee table                  Coffeemaker
# Coin                          Common fig                    Common sunflower
# Computer keyboard             Computer monitor              Computer mouse
# Container                     Convenience store             Cookie
# Cooking spray                 Corded phone                  Cosmetics
# Couch                         Countertop                    Cowboy hat
# Crab                          Cream                         Cricket ball
# Crocodile                     Croissant                     Crown
# Crutch                        Cucumber                      Cupboard
# Curtain                       Cutting board                 Dagger
# Dairy Product                 Deer                          Desk
# Dessert                       Diaper                        Dice
# Digital clock                 Dinosaur                      Dishwasher
# Dog                           Dog bed                       Doll
# Dolphin                       Door                          Door handle
# Doughnut                      Dragonfly                     Drawer
# Dress                         Drill (Tool)                  Drink
# Drinking straw                Drum                          Duck
# Dumbbell                      Eagle                         Earrings
# Egg (Food)                    Elephant                      Envelope
# Eraser                        Face powder                   Facial tissue holder
# Falcon                        Fashion accessory             Fast food
# Fax                           Fedora                        Filing cabinet
# Fire hydrant                  Fireplace                     Fish
# Flag                          Flashlight                    Flower
# Flowerpot                     Flute                         Flying disc
# Food                          Food processor                Football
# Football helmet               Footwear                      Fork
# Fountain                      Fox                           French fries
# French horn                   Frog                          Fruit
# Frying pan                    Furniture                     Garden Asparagus
# Gas stove                     Giraffe                       Girl
# Glasses                       Glove                         Goat
# Goggles                       Goldfish                      Golf ball
# Golf cart                     Gondola                       Goose
# Grape                         Grapefruit                    Grinder
# Guacamole                     Guitar                        Hair dryer
# Hair spray                    Hamburger                     Hammer
# Hamster                       Hand dryer                    Handbag
# Handgun                       Harbor seal                   Harmonica
# Harp                          Harpsichord                   Hat
# Headphones                    Heater                        Hedgehog
# Helicopter                    Helmet                        High heels
# Hiking equipment              Hippopotamus                  Home appliance
# Honeycomb                     Horizontal bar                Horse
# Hot dog                       House                         Houseplant
# Human arm                     Human beard                   Human body
# Human ear                     Human eye                     Human face
# Human foot                    Human hair                    Human hand
# Human head                    Human leg                     Human mouth
# Human nose                    Humidifier                    Ice cream
# Indoor rower                  Infant bed                    Insect
# Invertebrate                  Ipod                          Isopod
# Jacket                        Jacuzzi                       Jaguar (Animal)
# Jeans                         Jellyfish                     Jet ski
# Jug                           Juice                         Kangaroo
# Kettle                        Kitchen & dining room table   Kitchen appliance
# Kitchen knife                 Kitchen utensil               Kitchenware
# Kite                          Knife                         Koala
# Ladder                        Ladle                         Ladybug
# Lamp                          Land vehicle                  Lantern
# Laptop                        Lavender (Plant)              Lemon
# Leopard                       Light bulb                    Light switch
# Lighthouse                    Lily                          Limousine
# Lion                          Lipstick                      Lizard
# Lobster                       Loveseat                      Luggage and bags
# Lynx                          Magpie                        Mammal
# Man                           Mango                         Maple
# Maracas                       Marine invertebrates          Marine mammal
# Measuring cup                 Mechanical fan                Medical equipment
# Microphone                    Microwave oven                Milk
# Miniskirt                     Mirror                        Missile
# Mixer                         Mixing bowl                   Mobile phone
# Monkey                        Moths and butterflies         Motorcycle
# Mouse                         Muffin                        Mug
# Mule                          Mushroom                      Musical instrument
# Musical keyboard              Nail (Construction)           Necklace
# Nightstand                    Oboe                          Office building
# Office supplies               Orange                        Organ (Musical Instrument)
# Ostrich                       Otter                         Oven
# Owl                           Oyster                        Paddle
# Palm tree                     Pancake                       Panda
# Paper cutter                  Paper towel                   Parachute
# Parking meter                 Parrot                        Pasta
# Pastry                        Peach                         Pear
# Pen                           Pencil case                   Pencil sharpener
# Penguin                       Perfume                       Person
# Personal care                 Personal flotation device     Piano
# Picnic basket                 Picture frame                 Pig
# Pillow                        Pineapple                     Pitcher (Container)
# Pizza                         Pizza cutter                  Plant
# Plastic bag                   Plate                         Platter
# Plumbing fixture              Polar bear                    Pomegranate
# Popcorn                       Porch                         Porcupine
# Poster                        Potato                        Power plugs and sockets
# Pressure cooker               Pretzel                       Printer
# Pumpkin                       Punching bag                  Rabbit
# Raccoon                       Racket                        Radish
# Ratchet (Device)              Raven                         Rays and skates
# Red panda                     Refrigerator                  Remote control
# Reptile                       Rhinoceros                    Rifle
# Ring binder                   Rocket                        Roller skates
# Rose                          Rugby ball                    Ruler
# Salad                         Salt and pepper shakers       Sandal
# Sandwich                      Saucer                        Saxophone
# Scale                         Scarf                         Scissors
# Scoreboard                    Scorpion                      Screwdriver
# Sculpture                     Sea lion                      Sea turtle
# Seafood                       Seahorse                      Seat belt
# Segway                        Serving tray                  Sewing machine
# Shark                         Sheep                         Shelf
# Shellfish                     Shirt                         Shorts
# Shotgun                       Shower                        Shrimp
# Sink                          Skateboard                    Ski
# Skirt                         Skull                         Skunk
# Skyscraper                    Slow cooker                   Snack
# Snail                         Snake                         Snowboard
# Snowman                       Snowmobile                    Snowplow
# Soap dispenser                Sock                          Sofa bed
# Sombrero                      Sparrow                       Spatula
# Spice rack                    Spider                        Spoon
# Sports equipment              Sports uniform                Squash (Plant)
# Squid                         Squirrel                      Stairs
# Stapler                       Starfish                      Stationary bicycle
# Stethoscope                   Stool                         Stop sign
# Strawberry                    Street light                  Stretcher
# Studio couch                  Submarine                     Submarine sandwich
# Suit                          Suitcase                      Sun hat
# Sunglasses                    Surfboard                     Sushi
# Swan                          Swim cap                      Swimming pool
# Swimwear                      Sword                         Syringe
# Table                         Table tennis racket           Tablet computer
# Tableware                     Taco                          Tank
# Tap                           Tart                          Taxi
# Tea                           Teapot                        Teddy bear
# Telephone                     Television                    Tennis ball
# Tennis racket                 Tent                          Tiara
# Tick                          Tie                           Tiger
# Tin can                       Tire                          Toaster
# Toilet                        Toilet paper                  Tomato
# Tool                          Toothbrush                    Torch
# Tortoise                      Towel                         Tower
# Toy                           Traffic light                 Traffic sign
# Train                         Training bench                Treadmill
# Tree                          Tree house                    Tripod
# Trombone                      Trousers                      Truck
# Trumpet                       Turkey                        Turtle
# Umbrella                      Unicycle                      Van
# Vase                          Vegetable                     Vehicle
# Vehicle registration plate    Violin                        Volleyball (Ball)
# Waffle                        Waffle iron                   Wall clock
# Wardrobe                      Washing machine               Waste container
# Watch                         Watercraft                    Watermelon
# Weapon                        Whale                         Wheel
# Wheelchair                    Whisk                         Whiteboard
# Willow                        Window                        Window blind
# Wine                          Wine glass                    Wine rack
# Winter melon                  Wok                           Woman
# Wood-burning stove            Woodpecker                    Worm
# Wrench                        Zebra                         Zucchini

# %%
dest = "."
category = "Car"

# %%
info("Starting... ")
info(f"Downloading into {dest}")
categories_query = "https://storage.googleapis.com/openimages/web/visualizer/annotations_detection_train/categ2name.json"
response = requests.get(categories_query)
info("Getting categories....")

# save the json file
classes_json = "classes.json"
f = open(classes_json, "w")
f.write(response.text)
f.close()

# open json and load into a dict
f = open(classes_json, "r")
content = f.read()
classes = json.loads(content)
f.close()



classes
# Out:
# [INFO] Starting...
# [INFO] Downloading into .
# [INFO] Getting categories....
# {'/m/011k07': 'Tortoise',
#  '/m/011q46kg': 'Container',
#  '/m/012074': 'Magpie',
#  '/m/0120dh': 'Sea turtle',
#  '/m/01226z': 'Football',
#  '/m/012n7d': 'Ambulance',
#  '/m/012w5l': 'Ladder',
#  '/m/012xff': 'Toothbrush',
#  '/m/012ysf': 'Syringe',
#  '/m/0130jx': 'Sink',
#  '/m/0138tl': 'Toy',
#  '/m/013y1f': 'Organ (Musical Instrument)',
#  '/m/01432t': 'Cassette deck',
#  '/m/014j1m': 'Apple',
#  '/m/014sv8': 'Human eye',
#  '/m/014trl': 'Cosmetics',
#  '/m/014y4n': 'Paddle',
#  '/m/0152hh': 'Snowman',
#  '/m/01599': 'Beer',
#  '/m/015h_t': 'Human beard',
#  '/m/015p6': 'Bird',
#  '/m/015qbp': 'Parking meter',
#  '/m/015qff': 'Traffic light',
#  '/m/015wgc': 'Croissant',
#  '/m/015x4r': 'Cucumber',
#  '/m/015x5n': 'Radish',
#  '/m/0162_1': 'Towel',
#  '/m/0167gd': 'Doll',
#  '/m/016m2d': 'Skull',
#  '/m/0174k2': 'Washing machine',
#  '/m/0174n1': 'Glove',
#  '/m/0175cv': 'Tick',
#  '/m/0176mf': 'Belt',
#  '/m/017ftj': 'Sunglasses',
#  '/m/018j2': 'Banjo',
#  '/m/018p4k': 'Cart',
#  '/m/018xm': 'Ball',
#  '/m/01940j': 'Backpack',
#  '/m/0199g': 'Bicycle',
#  '/m/019dx1': 'Home appliance',
#  '/m/019h78': 'Centipede',
#  '/m/019jd': 'Boat',
#  '/m/019w40': 'Surfboard',
#  '/m/01_5g': 'Chopsticks',
#  '/m/01_bhs': 'Fast food',
#  '/m/01b638': 'Boot',
#  '/m/01b7fy': 'Headphones',
#  '/m/01b9xk': 'Hot dog',
#  '/m/01bfm9': 'Shorts',
#  '/m/01bjv': 'Bus',
#  '/m/01bl7v': 'Boy',
#  '/m/01bms0': 'Screwdriver',
#  '/m/01bqk0': 'Bicycle wheel',
#  '/m/01btn': 'Barge',
#  '/m/01c648': 'Laptop',
#  '/m/01cmb2': 'Miniskirt',
#  '/m/01d380': 'Drill (Tool)',
#  '/m/01d40f': 'Dress',
#  '/m/01dws': 'Bear',
#  '/m/01dwsz': 'Waffle',
#  '/m/01dwwc': 'Pancake',
#  '/m/01dxs': 'Brown bear',
#  '/m/01dy8n': 'Woodpecker',
#  '/m/01f8m5': 'Blue jay',
#  '/m/01f91_': 'Pretzel',
#  '/m/01fb_0': 'Bagel',
#  '/m/01fdzj': 'Tower',
#  '/m/01fh4r': 'Teapot',
#  '/m/01g317': 'Person',
#  '/m/01g3x7': 'Bow and arrow',
#  '/m/01gkx_': 'Swimwear',
#  '/m/01gllr': 'Beehive',
#  '/m/01gmv2': 'Brassiere',
#  '/m/01h3n': 'Bee',
#  '/m/01h44': 'Bat (Animal)',
#  '/m/01h8tj': 'Starfish',
#  '/m/01hrv5': 'Popcorn',
#  '/m/01j3zr': 'Burrito',
#  '/m/01j4z9': 'Chainsaw',
#  '/m/01j51': 'Balloon',
#  '/m/01j5ks': 'Wrench',
#  '/m/01j61q': 'Tent',
#  '/m/01jfm_': 'Vehicle registration plate',
#  '/m/01jfsr': 'Lantern',
#  '/m/01k6s3': 'Toaster',
#  '/m/01kb5b': 'Flashlight',
#  '/m/01knjb': 'Billboard',
#  '/m/01krhy': 'Tiara',
#  '/m/01lcw4': 'Limousine',
#  '/m/01llwg': 'Necklace',
#  '/m/01lrl': 'Carnivore',
#  '/m/01lsmm': 'Scissors',
#  '/m/01lynh': 'Stairs',
#  '/m/01m2v': 'Computer keyboard',
#  '/m/01m4t': 'Printer',
#  '/m/01mqdt': 'Traffic sign',
#  '/m/01mzpv': 'Chair',
#  '/m/01n4qj': 'Shirt',
#  '/m/01n5jq': 'Poster',
#  '/m/01nkt': 'Cheese',
#  '/m/01nq26': 'Sock',
#  '/m/01pns0': 'Fire hydrant',
#  '/m/01prls': 'Land vehicle',
#  '/m/01r546': 'Earrings',
#  '/m/01rkbr': 'Tie',
#  '/m/01rzcn': 'Watercraft',
#  '/m/01s105': 'Cabinetry',
#  '/m/01s55n': 'Suitcase',
#  '/m/01tcjp': 'Muffin',
#  '/m/01vbnl': 'Bidet',
#  '/m/01ww8y': 'Snack',
#  '/m/01x3jk': 'Snowmobile',
#  '/m/01x3z': 'Clock',
#  '/m/01x_v': 'Camel',
#  '/m/01xgg_': 'Medical equipment',
#  '/m/01xq0k1': 'Cattle',
#  '/m/01xqw': 'Cello',
#  '/m/01xs3r': 'Jet ski',
#  '/m/01xygc': 'Coat',
#  '/m/01xyhv': 'Suit',
#  '/m/01y9k5': 'Desk',
#  '/m/01yrx': 'Cat',
#  '/m/01yx86': 'Bronze sculpture',
#  '/m/01z1kdw': 'Juice',
#  '/m/02068x': 'Gondola',
#  '/m/020jm': 'Beetle',
#  '/m/020kz': 'Cannon',
#  '/m/020lf': 'Computer mouse',
#  '/m/021mn': 'Cookie',
#  '/m/021sj1': 'Office building',
#  '/m/0220r2': 'Fountain',
#  '/m/0242l': 'Coin',
#  '/m/024d2': 'Calculator',
#  '/m/024g6': 'Cocktail',
#  '/m/02522': 'Computer monitor',
#  '/m/025dyy': 'Box',
#  '/m/025fsf': 'Stapler',
#  '/m/025nd': 'Christmas tree',
#  '/m/025rp__': 'Cowboy hat',
#  '/m/0268lbt': 'Hiking equipment',
#  '/m/026qbn5': 'Studio couch',
#  '/m/026t6': 'Drum',
#  '/m/0270h': 'Dessert',
#  '/m/0271qf7': 'Wine rack',
#  '/m/0271t': 'Drink',
#  '/m/027pcv': 'Zucchini',
#  '/m/027rl48': 'Ladle',
#  '/m/0283dt1': 'Human mouth',
#  '/m/0284d': 'Dairy Product',
#  '/m/029b3': 'Dice',
#  '/m/029bxz': 'Oven',
#  '/m/029tx': 'Dinosaur',
#  '/m/02_n6y': 'Goggles',
#  '/m/02bm9n': 'Ratchet (Device)',
#  '/m/02crq1': 'Couch',
#  '/m/02ctlc': 'Cricket ball',
#  '/m/02cvgx': 'Winter melon',
#  '/m/02d1br': 'Spatula',
#  '/m/02d9qx': 'Whiteboard',
#  '/m/02ddwp': 'Pencil sharpener',
#  '/m/02dgv': 'Door',
#  '/m/02dl1y': 'Hat',
#  '/m/02f9f_': 'Shower',
#  '/m/02fh7f': 'Eraser',
#  '/m/02fq_6': 'Fedora',
#  '/m/02g30s': 'Guacamole',
#  '/m/02gzp': 'Dagger',
#  '/m/02h19r': 'Scarf',
#  '/m/02hj4': 'Dolphin',
#  '/m/02jfl0': 'Sombrero',
#  '/m/02jnhm': 'Tin can',
#  '/m/02jvh9': 'Mug',
#  '/m/02jz0l': 'Tap',
#  '/m/02l8p9': 'Harbor seal',
#  '/m/02lbcq': 'Stretcher',
#  '/m/02mqfb': 'Can opener',
#  '/m/02p0tk3': 'Human body',
#  '/m/02p3w7d': 'Roller skates',
#  '/m/02p5f1q': 'Coffee cup',
#  '/m/02pdsw': 'Cutting board',
#  '/m/02pjr4': 'Blender',
#  '/m/02pkr5': 'Plumbing fixture',
#  '/m/02pv19': 'Stop sign',
#  '/m/02rdsp': 'Office supplies',
#  '/m/02rgn06': 'Volleyball (Ball)',
#  '/m/02s195': 'Vase',
#  '/m/02tsc9': 'Slow cooker',
#  '/m/02vkqh8': 'Wardrobe',
#  '/m/02vqfm': 'Coffee',
#  '/m/02vwcm': 'Whisk',
#  '/m/02w3_ws': 'Personal care',
#  '/m/02w3r3': 'Paper towel',
#  '/m/02wbm': 'Food',
#  '/m/02wbtzl': 'Sun hat',
#  '/m/02wg_p': 'Tree house',
#  '/m/02wmf': 'Flying disc',
#  '/m/02wv6h6': 'Skirt',
#  '/m/02wv84t': 'Gas stove',
#  '/m/02x8cch': 'Salt and pepper shakers',
#  '/m/02x984l': 'Mechanical fan',
#  '/m/02xb7qb': 'Face powder',
#  '/m/02xqq': 'Fax',
#  '/m/02xwb': 'Fruit',
#  '/m/02y6n': 'French fries',
#  '/m/02z51p': 'Nightstand',
#  '/m/02zn6n': 'Barrel',
#  '/m/02zt3': 'Kite',
#  '/m/02zvsm': 'Tart',
#  '/m/030610': 'Treadmill',
#  '/m/0306r': 'Fox',
#  '/m/03120': 'Flag',
#  '/m/0319l': 'French horn',
#  '/m/031b6r': 'Window blind',
#  '/m/031n1': 'Human foot',
#  '/m/0323sq': 'Golf cart',
#  '/m/032b3c': 'Jacket',
#  '/m/033cnk': 'Egg (Food)',
#  '/m/033rq4': 'Street light',
#  '/m/0342h': 'Guitar',
#  '/m/034c16': 'Pillow',
#  '/m/035r7c': 'Human leg',
#  '/m/035vxb': 'Isopod',
#  '/m/0388q': 'Grape',
#  '/m/039xj_': 'Human ear',
#  '/m/03__z0': 'Bookcase',
#  '/m/03_wxk': 'Kitchenware',
#  '/m/03bbps': 'Power plugs and sockets',
#  '/m/03bj1': 'Panda',
#  '/m/03bk1': 'Giraffe',
#  '/m/03bt1vf': 'Woman',
#  '/m/03c7gz': 'Door handle',
#  '/m/03d443': 'Rhinoceros',
#  '/m/03dnzn': 'Bathtub',
#  '/m/03fj2': 'Goldfish',
#  '/m/03fp41': 'Houseplant',
#  '/m/03fwl': 'Goat',
#  '/m/03g8mr': 'Baseball bat',
#  '/m/03grzl': 'Baseball glove',
#  '/m/03hj559': 'Mixing bowl',
#  '/m/03hl4l9': 'Marine invertebrates',
#  '/m/03hlz0c': 'Kitchen utensil',
#  '/m/03jbxj': 'Light switch',
#  '/m/03jm5': 'House',
#  '/m/03k3r': 'Horse',
#  '/m/03kt2w': 'Stationary bicycle',
#  '/m/03l9g': 'Hammer',
#  '/m/03ldnb': 'Ceiling fan',
#  '/m/03m3pdh': 'Sofa bed',
#  '/m/03m3vtv': 'Adhesive tape',
#  '/m/03m5k': 'Harp',
#  '/m/03nfch': 'Sandal',
#  '/m/03p3bw': 'Bicycle helmet',
#  '/m/03q5c7': 'Saucer',
#  '/m/03q5t': 'Harpsichord',
#  '/m/03q69': 'Human hair',
#  '/m/03qhv5': 'Heater',
#  '/m/03qjg': 'Harmonica',
#  '/m/03qrc': 'Hamster',
#  '/m/03rszm': 'Curtain',
#  '/m/03s_tn': 'Kettle',
#  '/m/03ssj5': 'Bed',
#  '/m/03tw93': 'Fireplace',
#  '/m/03txqz': 'Scale',
#  '/m/03v5tg': 'Drinking straw',
#  '/m/03vt0': 'Insect',
#  '/m/03wvsk': 'Hair dryer',
#  '/m/03wym': 'Indoor rower',
#  '/m/03xxp': 'Invertebrate',
#  '/m/03y6mg': 'Food processor',
#  '/m/040b_t': 'Refrigerator',
#  '/m/04169hn': 'Wood-burning stove',
#  '/m/0420v5': 'Punching bag',
#  '/m/043nyj': 'Common fig',
#  '/m/0440zs': 'Cocktail shaker',
#  '/m/0449p': 'Jaguar (Animal)',
#  '/m/044r5d': 'Golf ball',
#  '/m/0463sg': 'Fashion accessory',
#  '/m/046dlr': 'Alarm clock',
#  '/m/047j0r': 'Filing cabinet',
#  '/m/047v4b': 'Artichoke',
#  '/m/04_sv': 'Motorcycle',
#  '/m/04bcr3': 'Table',
#  '/m/04brg2': 'Tableware',
#  '/m/04c0y': 'Kangaroo',
#  '/m/04cp_': 'Koala',
#  '/m/04ctx': 'Knife',
#  '/m/04dr76w': 'Bottle',
#  '/m/04f5ws': 'Bottle opener',
#  '/m/04g2r': 'Lynx',
#  '/m/04gth': 'Lavender (Plant)',
#  '/m/04h7h': 'Lighthouse',
#  '/m/04h8sr': 'Dumbbell',
#  '/m/04hgtk': 'Human head',
#  '/m/04kkgm': 'Bowl',
#  '/m/04lvq_': 'Humidifier',
#  '/m/04m6gz': 'Porch',
#  '/m/04m9y': 'Lizard',
#  '/m/04p0qw': 'Billiard table',
#  '/m/04rky': 'Mammal',
#  '/m/04rmv': 'Mouse',
#  '/m/04szw': 'Musical instrument',
#  '/m/04tn4x': 'Swim cap',
#  '/m/04v6l4': 'Frying pan',
#  '/m/04vv5k': 'Snowplow',
#  '/m/04y4h8h': 'Bathroom cabinet',
#  '/m/04ylt': 'Missile',
#  '/m/04yqq2': 'Bust',
#  '/m/04yx4': 'Man',
#  '/m/04z4wx': 'Waffle iron',
#  '/m/04zpv': 'Milk',
#  '/m/04zwwv': 'Ring binder',
#  '/m/050gv4': 'Plate',
#  '/m/050k8': 'Mobile phone',
#  '/m/052lwg6': 'Baked goods',
#  '/m/052sf': 'Mushroom',
#  '/m/05441v': 'Crutch',
#  '/m/054_l': 'Mirror',
#  '/m/054fyh': 'Pitcher (Container)',
#  '/m/054xkw': 'Personal flotation device',
#  '/m/05676x': 'Pencil case',
#  '/m/057cc': 'Musical keyboard',
#  '/m/057p5t': 'Scoreboard',
#  '/m/0584n8': 'Briefcase',
#  '/m/058qzx': 'Kitchen knife',
#  '/m/05_5p_0': 'Table tennis racket',
#  '/m/05bm6': 'Nail (Construction)',
#  '/m/05ctyq': 'Tennis ball',
#  '/m/05gqfk': 'Plastic bag',
#  '/m/05kms': 'Oboe',
#  '/m/05kyg_': 'Chest of drawers',
#  '/m/05n4y': 'Ostrich',
#  '/m/05r5c': 'Piano',
#  '/m/05r655': 'Girl',
#  '/m/05s2s': 'Plant',
#  '/m/05vtc': 'Potato',
#  '/m/05w9t9': 'Hair spray',
#  '/m/05y5lj': 'Sports equipment',
#  '/m/05z55': 'Pasta',
#  '/m/05z6w': 'Penguin',
#  '/m/05zsy': 'Pumpkin',
#  '/m/061_f': 'Pear',
#  '/m/061hd_': 'Infant bed',
#  '/m/0633h': 'Polar bear',
#  '/m/063rgb': 'Mixer',
#  '/m/0642b4': 'Cupboard',
#  '/m/065h6l': 'Jacuzzi',
#  '/m/0663v': 'Pizza',
#  '/m/068zj': 'Pig',
#  '/m/06_72j': 'Digital clock',
#  '/m/06__v': 'Snowboard',
#  '/m/06_fw': 'Skateboard',
#  '/m/06bt6': 'Reptile',
#  '/m/06c54': 'Rifle',
#  '/m/06c7f7': 'Lipstick',
#  '/m/06j2d': 'Raven',
#  '/m/06k2mb': 'High heels',
#  '/m/06l9r': 'Red panda',
#  '/m/06m11': 'Rose',
#  '/m/06mf6': 'Rabbit',
#  '/m/06msq': 'Sculpture',
#  '/m/06ncr': 'Saxophone',
#  '/m/06nrc': 'Shotgun',
#  '/m/06nwz': 'Seafood',
#  '/m/06pcq': 'Submarine sandwich',
#  '/m/06y5r': 'Sword',
#  '/m/06z37_': 'Picture frame',
#  '/m/07030': 'Sushi',
#  '/m/0703r8': 'Loveseat',
#  '/m/071p9': 'Ski',
#  '/m/071qp': 'Squirrel',
#  '/m/073bxn': 'Tripod',
#  '/m/073g6': 'Stethoscope',
#  '/m/074d1': 'Submarine',
#  '/m/0755b': 'Scorpion',
#  '/m/076bq': 'Segway',
#  '/m/076lb9': 'Training bench',
#  '/m/078jl': 'Snake',
#  '/m/078n6m': 'Coffee table',
#  '/m/079cl': 'Skyscraper',
#  '/m/07bgp': 'Sheep',
#  '/m/07c52': 'Television',
#  '/m/07c6l': 'Trombone',
#  '/m/07clx': 'Tea',
#  '/m/07cmd': 'Tank',
#  '/m/07crc': 'Taco',
#  '/m/07cx4': 'Telephone',
#  '/m/07dd4': 'Torch',
#  '/m/07dm6': 'Tiger',
#  '/m/07fbm7': 'Strawberry',
#  '/m/07gql': 'Trumpet',
#  '/m/07j7r': 'Tree',
#  '/m/07j87': 'Tomato',
#  '/m/07jdr': 'Train',
#  '/m/07k1x': 'Tool',
#  '/m/07kng9': 'Picnic basket',
#  '/m/07mcwg': 'Cooking spray',
#  '/m/07mhn': 'Trousers',
#  '/m/07pj7bq': 'Bowling equipment',
#  '/m/07qxg_': 'Football helmet',
#  '/m/07r04': 'Truck',
#  '/m/07v9_z': 'Measuring cup',
#  '/m/07xyvk': 'Coffeemaker',
#  '/m/07y_7': 'Violin',
#  '/m/07yv9': 'Vehicle',
#  '/m/080hkjn': 'Handbag',
#  '/m/080n7g': 'Paper cutter',
#  '/m/081qc': 'Wine',
#  '/m/083kb': 'Weapon',
#  '/m/083wq': 'Wheel',
#  '/m/084hf': 'Worm',
#  '/m/084rd': 'Wok',
#  '/m/084zz': 'Whale',
#  '/m/0898b': 'Zebra',
#  '/m/08dz3q': 'Auto part',
#  '/m/08hvt4': 'Jug',
#  '/m/08ks85': 'Pizza cutter',
#  '/m/08p92x': 'Cream',
#  '/m/08pbxl': 'Monkey',
#  '/m/096mb': 'Lion',
#  '/m/09728': 'Bread',
#  '/m/099ssp': 'Platter',
#  '/m/09b5t': 'Chicken',
#  '/m/09csl': 'Eagle',
#  '/m/09ct_': 'Helicopter',
#  '/m/09d5_': 'Owl',
#  '/m/09ddx': 'Duck',
#  '/m/09dzg': 'Turtle',
#  '/m/09f20': 'Hippopotamus',
#  '/m/09f_2': 'Crocodile',
#  '/m/09g1w': 'Toilet',
#  '/m/09gtd': 'Toilet paper',
#  '/m/09gys': 'Squid',
#  '/m/09j2d': 'Clothing',
#  '/m/09j5n': 'Footwear',
#  '/m/09k_b': 'Lemon',
#  '/m/09kmb': 'Spider',
#  '/m/09kx5': 'Deer',
#  '/m/09ld4': 'Frog',
#  '/m/09qck': 'Banana',
#  '/m/09rvcxw': 'Rocket',
#  '/m/09tvcd': 'Wine glass',
#  '/m/0_cp5': 'Oyster',
#  '/m/0_dqb': 'Chisel',
#  '/m/0_k2': 'Ant',
#  '/m/0b3fp9': 'Countertop',
#  '/m/0b_rs': 'Swimming pool',
#  '/m/0bh9flk': 'Tablet computer',
#  '/m/0bjyj5': 'Waste container',
#  '/m/0bt9lr': 'Dog',
#  '/m/0bt_c3': 'Book',
#  '/m/0bwd_0j': 'Elephant',
#  '/m/0by6g': 'Shark',
#  '/m/0c06p': 'Candle',
#  '/m/0c29q': 'Leopard',
#  '/m/0c2jj': 'Axe',
#  '/m/0c3m8g': 'Hand dryer',
#  '/m/0c3mkw': 'Soap dispenser',
#  '/m/0c568': 'Porcupine',
#  '/m/0c9ph5': 'Flower',
#  '/m/0c_jw': 'Furniture',
#  '/m/0ccs93': 'Canary',
#  '/m/0cd4d': 'Cheetah',
#  '/m/0cdl1': 'Palm tree',
#  '/m/0cdn1': 'Hamburger',
#  '/m/0cffdh': 'Maple',
#  '/m/0cgh4': 'Building',
#  '/m/0ch_cf': 'Fish',
#  '/m/0cjq5': 'Lobster',
#  '/m/0cjs7': 'Garden Asparagus',
#  '/m/0cl4p': 'Hedgehog',
#  '/m/0cmf2': 'Airplane',
#  '/m/0cmx8': 'Spoon',
#  '/m/0cn6p': 'Otter',
#  '/m/0cnyhnx': 'Bull',
#  '/m/0cqn2': 'Horizontal bar',
#  '/m/0crjs': 'Convenience store',
#  '/m/0ct4f': 'Bomb',
#  '/m/0cvnqh': 'Bench',
#  '/m/0cxn2': 'Ice cream',
#  '/m/0cydv': 'Caterpillar',
#  '/m/0cyf8': 'Butterfly',
#  '/m/0cyfs': 'Parachute',
#  '/m/0cyhj_': 'Orange',
#  '/m/0czz2': 'Antelope',
#  '/m/0d20w4': 'Beaker',
#  '/m/0d4v4': 'Window',
#  '/m/0d4w1': 'Closet',
#  '/m/0d5gx': 'Castle',
#  '/m/0d8zb': 'Jellyfish',
#  '/m/0d_2m': 'Moths and butterflies',
#  '/m/0dbvp': 'Goose',
#  '/m/0dbzx': 'Mule',
#  '/m/0dftk': 'Swan',
#  '/m/0dj6p': 'Peach',
#  '/m/0djtd': 'Coconut',
#  '/m/0dkzw': 'Seat belt',
#  '/m/0dq75': 'Raccoon',
#  '/m/0dt3t': 'Fork',
#  '/m/0dtln': 'Lamp',
#  '/m/0dv5r': 'Camera',
#  '/m/0dv77': 'Squash (Plant)',
#  '/m/0dv9c': 'Racket',
#  '/m/0dzct': 'Human face',
#  '/m/0dzf4': 'Human arm',
#  '/m/0f4s2w': 'Vegetable',
#  '/m/0f571': 'Diaper',
#  '/m/0f6nr': 'Unicycle',
#  '/m/0f6wt': 'Falcon',
#  '/m/0f8s22': 'Chime',
#  '/m/0f9_l': 'Snail',
#  '/m/0fbdv': 'Shellfish',
#  '/m/0fbw6': 'Cabbage',
#  '/m/0fj52s': 'Carrot',
#  '/m/0fldg': 'Mango',
#  '/m/0fly7': 'Jeans',
#  '/m/0fm3zh': 'Flowerpot',
#  '/m/0fp6w': 'Pineapple',
#  '/m/0fqfqc': 'Drawer',
#  '/m/0fqt361': 'Stool',
#  '/m/0frqm': 'Envelope',
#  '/m/0fszt': 'Cake',
#  '/m/0ft9s': 'Dragonfly',
#  '/m/0ftb8': 'Common sunflower',
#  '/m/0fx9l': 'Microwave oven',
#  '/m/0fz0h': 'Honeycomb',
#  '/m/0gd2v': 'Marine mammal',
#  '/m/0gd36': 'Sea lion',
#  '/m/0gj37': 'Ladybug',
#  '/m/0gjbg72': 'Shelf',
#  '/m/0gjkl': 'Watch',
#  '/m/0gm28': 'Candy',
#  '/m/0grw1': 'Salad',
#  '/m/0gv1x': 'Parrot',
#  '/m/0gxl3': 'Handgun',
#  '/m/0h23m': 'Sparrow',
#  '/m/0h2r6': 'Van',
#  '/m/0h8jyh6': 'Grinder',
#  '/m/0h8kx63': 'Spice rack',
#  '/m/0h8l4fh': 'Light bulb',
#  '/m/0h8lkj8': 'Corded phone',
#  '/m/0h8mhzd': 'Sports uniform',
#  '/m/0h8my_4': 'Tennis racket',
#  '/m/0h8mzrc': 'Wall clock',
#  '/m/0h8n27j': 'Serving tray',
#  '/m/0h8n5zk': 'Kitchen & dining room table',
#  '/m/0h8n6f9': 'Dog bed',
#  '/m/0h8n6ft': 'Cake stand',
#  '/m/0h8nm9j': 'Cat furniture',
#  '/m/0h8nr_l': 'Bathroom accessory',
#  '/m/0h8nsvg': 'Facial tissue holder',
#  '/m/0h8ntjv': 'Pressure cooker',
#  '/m/0h99cwc': 'Kitchen appliance',
#  '/m/0h9mv': 'Tire',
#  '/m/0hdln': 'Ruler',
#  '/m/0hf58v5': 'Luggage and bags',
#  '/m/0hg7b': 'Microphone',
#  '/m/0hkxq': 'Broccoli',
#  '/m/0hnnb': 'Umbrella',
#  '/m/0hnyx': 'Pastry',
#  '/m/0hqkz': 'Grapefruit',
#  '/m/0j496': 'Band-aid',
#  '/m/0jbk': 'Animal',
#  '/m/0jg57': 'Bell pepper',
#  '/m/0jly1': 'Turkey',
#  '/m/0jqgx': 'Lily',
#  '/m/0jwn_': 'Pomegranate',
#  '/m/0jy4k': 'Doughnut',
#  '/m/0jyfg': 'Glasses',
#  '/m/0k0pj': 'Human nose',
#  '/m/0k1tl': 'Pen',
#  '/m/0k4j': 'Car',
#  '/m/0k5j': 'Aircraft',
#  '/m/0k65p': 'Human hand',
#  '/m/0km7z': 'Skunk',
#  '/m/0kmg4': 'Teddy bear',
#  '/m/0kpqd': 'Watermelon',
#  '/m/0kpt_': 'Cantaloupe',
#  '/m/0ky7b': 'Dishwasher',
#  '/m/0l14j_': 'Flute',
#  '/m/0l3ms': 'Balance beam',
#  '/m/0l515': 'Sandwich',
#  '/m/0ll1f78': 'Shrimp',
#  '/m/0llzx': 'Sewing machine',
#  '/m/0lt4_': 'Binoculars',
#  '/m/0m53l': 'Rays and skates',
#  '/m/0mcx2': 'Ipod',
#  '/m/0mkg': 'Accordion',
#  '/m/0mw_6': 'Willow',
#  '/m/0n28_': 'Crab',
#  '/m/0nl46': 'Crown',
#  '/m/0nybt': 'Seahorse',
#  '/m/0p833': 'Perfume',
#  '/m/0pcr': 'Alpaca',
#  '/m/0pg52': 'Taxi',
#  '/m/0ph39': 'Canoe',
#  '/m/0qjjc': 'Remote control',
#  '/m/0qmmr': 'Wheelchair',
#  '/m/0wdt60w': 'Rugby ball',
#  '/m/0xfy': 'Armadillo',
#  '/m/0xzly': 'Maracas',
#  '/m/0zvk5': 'Helmet'}

# %%
# convert {idx: class_name} to {class_name: idx}
new_classes = {}
for idx in classes:
    # replace '/' with '_' because the request contains '_'
    new_classes[classes[idx]] = f"{idx.replace('/', '_')}.json"

# create query to get the desired class
image_query = f"https://storage.googleapis.com/\
openimages/web/visualizer/annotations_detection_train/{new_classes[category]}"
print(image_query)
r = requests.get(image_query)
"""
https://storage.googleapis.com/openimages/web/visualizer/annotations_detection_train/categ_cooccur/_m_0k4j.json
https://storage.googleapis.comopenimages/web/visualizer/annotations_detection_train/categ_cooccur/_m_0k4j.json
https://storage.googleapis.com/openimages/web/visualizer/annotations_detection_train/_m_0k4j.json
"""
# Out:
# https://storage.googleapis.com/openimages/web/visualizer/annotations_detection_train/_m_0k4j.json
# '\nhttps://storage.googleapis.com/openimages/web/visualizer/annotations_detection_train/categ_cooccur/_m_0k4j.json\nhttps://storage.googleapis.comopenimages/web/visualizer/annotations_detection_train/categ_cooccur/_m_0k4j.json\nhttps://storage.googleapis.com/openimages/web/visualizer/annotations_detection_train/_m_0k4j.json\n'

# %%
print(image_query)
# Out:
# https://storage.googleapis.com/openimages/web/visualizer/annotations_detection_train/_m_0k4j.json

# %%
print(r.text)
content = r.text
# Out:
# ccluded"
#         ],
#         "bounding_box": {
#           "xmax": "0.2500",
#           "xmin": "0.0938",
#           "ymax": "0.7958",
#           "ymin": "0.7117"
#         },
#         "category": "/m/0k4j",
#         "text": "Car"
#       },
#       {
#         "attributes": [
#           "Occluded"
#         ],
#         "bounding_box": {
#           "xmax": "0.8769",
#           "xmin": "0.5175",
#           "ymax": "0.8717",
#           "ymin": "0.6775"
#         },
#         "category": "/m/0k4j",
#         "text": "Car"
#       }
#     ]
#   },
#   "feae1846566b7650": {
#     "image": {
#       "footnote": "Source URL: <a href='https://farm1.staticflickr.com/4076/4890835044_beacf88926_o.jpg' target='_blank'>Full Resolution</a>, <a href='https://c1.staticflickr.com/5/4076/4890835044_f0e99a9dbd_z.jpg' target='_blank'>Thumbnail</a>",
#       "footnote_bottom_right": "Author: <a href='https://www.flickr.com/people/mdpettitt/' target='_blank'>Martin Pettitt </a>(<a href='https://creativecommons.org/licenses/by/2.0/' target='_blank'>License</a>)",
#       "footnote_top_right": "Title: Big Wheels Car Show",
#       "rotation": 0.0,
#       "url": "https://c1.staticflickr.com/5/4076/4890835044_f0e99a9dbd_z.jpg",
#       "url_full_res": "https://farm1.staticflickr.com/4076/4890835044_beacf88926_o.jpg"
#     },
#     "image_labels": [
#       {
#         "category": "Person",
#         "confidence": 1
#       },
#       {
#         "category": "Land vehicle",
#         "confidence": 1
#       },
#       {
#         "category": "Vehicle",
#         "confidence": 1
#       },
#       {
#         "category": "Car",
#         "confidence": 1
#       }
#     ],
#     "objects": [
#       {
#         "attributes": [
#           "Occluded"
#         ],
#         "bounding_box": {
#           "xmax": "0.3031",
#           "xmin": "0.1881",
#           "ymax": "0.3567",
#           "ymin": "0.2511"
#         },
#         "category": "/m/01g317",
#         "text": "Person (Group)"
#       },
#       {
#         "attributes": [
#           "Occluded"
#         ],
#         "bounding_box": {
#           "xmax": "0.9631",
#           "xmin": "0.8325",
#           "ymax": "0.5133",
#           "ymin": "0.2700"
#         },
#         "category": "/m/01g317",
#         "text": "Person (Group)"
#       },
#       {
#         "attributes": [
#           "Occluded",
#           "Truncated"
#         ],
#         "bounding_box": {
#           "xmax": "0.9994",
#           "xmin": "0.0000",
#           "ymax": "0.7956",
#           "ymin": "0.1244"
#         },
#         "category": "/m/0k4j",
#         "text": "Car (Group)"
#       }
#     ]
#   },
#   "feb9f0007f42ea9f": {
#     "image": {
#       "footnote": "Source URL: <a href='https://c8.staticflickr.com/8/7484/15744515032_1fdb571d65_o.jpg' target='_blank'>Full Resolution</a>, <a href='https://c3.staticflickr.com/8/7484/15744515032_5421a033dd_z.jpg' target='_blank'>Thumbnail</a>",
#       "footnote_bottom_right": "Author: <a href='https://www.flickr.com/people/southbeachcars/' target='_blank'>Phillip Pessar </a>(<a href='https://creativecommons.org/licenses/by/2.0/' target='_blank'>License</a>)",
#       "footnote_top_right": "Title: Former Chevrolet Dealer  Showroom Being Restored 1924",
#       "rotation": 0.0,
#       "url": "https://c3.staticflickr.com/8/7484/15744515032_5421a033dd_z.jpg",
#       "url_full_res": "https://c8.staticflickr.com/8/7484/15744515032_1fdb571d65_o.jpg"
#     },
#     "image_labels": [
#       {
#         "category": "Land vehicle",
#         "confidence": 1
#       },
#       {
#         "category": "Tree",
#         "confidence": 1
#       },
#       {
#         "category": "Truck",
#         "confidence": 1
#       },
#       {
#         "category": "Vehicle",
#         "confidence": 1
#       },
#       {
#         "category": "Wheel",
#         "confidence": 1
#       },
#       {
#         "category": "Building",
#         "confidence": 0
#       },
#       {
#         "category": "Car",
#         "confidence": 1
#       }
#     ],
#     "objects": [
#       {
#         "attributes": [
#           "Occluded"
#         ],
#         "bounding_box": {
#           "xmax": "0.5350",
#           "xmin": "0.3681",
#           "ymax": "0.7923",
#           "ymin": "0.2923"
#         },
#         "category": "/m/07j7r",
#         "text": "Tree"
#       },
#       {
#         "attributes": [],
#         "bounding_box": {
#           "xmax": "0.3050",
#           "xmin": "0.0894",
#           "ymax": "0.8487",
#           "ymin": "0.7237"
#         },
#         "category": "/m/07r04",
#         "text": "Truck"
#       },
#       {
#         "attributes": [],
#         "bounding_box": {
#           "xmax": "0.3006",
#           "xmin": "0.0806",
#           "ymax": "0.8412",
#           "ymin": "0.7227"
#         },
#         "category": "/m/0k4j",
#         "text": "Car"
#       },
#       {
#         "attributes": [
#           "Occluded",
#           "Truncated"
#         ],
#         "bounding_box": {
#           "xmax": "0.9994",
#           "xmin": "0.8800",
#           "ymax": "0.8158",
#           "ymin": "0.3224"
#         },
#         "category": "/m/07j7r",
#         "text": "Tree"
#       },
#       {
#         "attributes": [
#           "Occluded"
#         ],
#         "bounding_box": {
#           "xmax": "0.1281",
#           "xmin": "0.0944",
#           "ymax": "0.8271",
#           "ymin": "0.7848"
#         },
#         "category": "/m/083wq",
#         "text": "Wheel"
#       },
#       {
#         "attributes": [
#           "Occluded"
#         ],
#         "bounding_box": {
#           "xmax": "0.1525",
#           "xmin": "0.1319",
#           "ymax": "0.8327",
#           "ymin": "0.8055"
#         },
#         "category": "/m/083wq",
#         "text": "Wheel"
#       },
#       {
#         "attributes": [],
#         "bounding_box": {
#           "xmax": "0.1638",
#           "xmin": "0.1550",
#           "ymax": "0.7650",
#           "ymin": "0.7491"
#         },
#         "category": "/m/083wq",
#         "text": "Wheel"
#       },
#       {
#         "attributes": [
#           "Occluded"
#         ],
#         "bounding_box": {
#           "xmax": "0.2581",
#           "xmin": "0.2281",
#           "ymax": "0.8318",
#           "ymin": "0.7895"
#         },
#         "category": "/m/083wq",
#         "text": "Wheel"
#       },
#       {
#         "attributes": [
#           "Occluded"
#         ],
#         "bounding_box": {
#           "xmax": "0.2781",
#           "xmin": "0.2600",
#           "ymax": "0.8308",
#           "ymin": "0.8148"
#         },
#         "category": "/m/083wq",
#         "text": "Wheel"
#       }
#     ]
#   },
#   "fed122b86a3fbfb9": {
#     "image": {
#       "footnote": "Source URL: <a href='https://c2.staticflickr.com/6/5100/5469996579_e98dc3e971_o.jpg' target='_blank'>Full Resolution</a>, <a href='https://c2.staticflickr.com/6/5100/5469996579_836f715d86_z.jpg' target='_blank'>Thumbnail</a>",
#       "footnote_bottom_right": "Author: <a href='https://www.flickr.com/people/marcus-bleil/' target='_blank'>Marcus Bleil </a>(<a href='https://creativecommons.org/licenses/by/2.0/' target='_blank'>License</a>)",
#       "footnote_top_right": "Title: Ulm 2010",
#       "rotation": 0.0,
#       "url": "https://c2.staticflickr.com/6/5100/5469996579_836f715d86_z.jpg",
#       "url_full_res": "https://c2.staticflickr.com/6/5100/5469996579_e98dc3e971_o.jpg"
#     },
#     "image_labels": [
#       {
#         "category": "Person",
#         "confidence": 1
#       },
#       {
#         "category": "Land vehicle",
#         "confidence": 1
#       },
#       {
#         "category": "House",
#         "confidence": 1
#       },
#       {
#         "category": "Man",
#         "confidence": 1
#       },
#       {
#         "category": "Vehicle",
#         "confidence": 1
#       },
#       {
#         "category": "Clothing",
#         "confidence": 1
#       },
#       {
#         "category": "Footwear",
#         "confidence": 1
#       },
#       {
#         "category": "Building",
#         "confidence": 1
#       },
#       {
#         "category": "Car",
#         "confidence": 1
#       }
#     ],
#     "objects": [
#       {
#         "attributes": [],
#         "bounding_box": {
#           "xmax": "0.9541",
#           "xmin": "0.1152",
#           "ymax": "0.8350",
#           "ymin": "0.0887"
#         },
#         "category": "/m/03jm5",
#         "text": "House"
#       },
#       {
#         "attributes": [],
#         "bounding_box": {
#           "xmax": "0.9967",
#           "xmin": "0.8623",
#           "ymax": "0.9444",
#           "ymin": "0.7994"
#         },
#         "category": "/m/04yx4",
#         "text": "Man"
#       },
#       {
#         "attributes": [],
#         "bounding_box": {
#           "xmax": "0.9007",
#           "xmin": "0.8689",
#           "ymax": "0.9569",
#           "ymin": "0.9313"
#         },
#         "category": "/m/09j5n",
#         "text": "Footwear"
#       },
#       {
#         "attributes": [
#           "Truncated"
#         ],
#         "bounding_box": {
#           "xmax": "0.9992",
#           "xmin": "0.9783",
#           "ymax": "0.9569",
#           "ymin": "0.9487"
#         },
#         "category": "/m/09j5n",
#         "text": "Footwear"
#       },
#       {
#         "attributes": [
#           "Occluded"
#         ],
#         "bounding_box": {
#           "xmax": "0.3464",
#           "xmin": "0.0292",
#           "ymax": "0.8669",
#           "ymin": "0.7794"
#         },
#         "category": "/m/0k4j",
#         "text": "Car"
#       },
#       {
#         "attributes": [],
#         "bounding_box": {
#           "xmax": "0.4583",
#           "xmin": "0.1227",
#           "ymax": "0.8806",
#           "ymin": "0.7762"
#         },
#         "category": "/m/0k4j",
#         "text": "Car"
#       }
#     ]
#   },
#   "ff044694a30f720e": {
#     "image": {
#       "footnote": "Source URL: <a href='https://c7.staticflickr.com/2/1204/1384108011_fc20d37b41_o.jpg' target='_blank'>Full Resolution</a>, <a href='https://c3.staticflickr.com/2/1204/1384108011_03763a12ab_z.jpg?zz=1' target='_blank'>Thumbnail</a>",
#       "footnote_bottom_right": "Author: <a href='https://www.flickr.com/people/free-stuff/' target='_blank'>Brian Chow </a>(<a href='https://creativecommons.org/licenses/by/2.0/' target='_blank'>License</a>)",
#       "footnote_top_right": "Title: IMG_3101",
#       "rotation": 0.0,
#       "url": "https://c3.staticflickr.com/2/1204/1384108011_03763a12ab_z.jpg?zz=1",
#       "url_full_res": "https://c7.staticflickr.com/2/1204/1384108011_fc20d37b41_o.jpg"
#     },
#     "image_labels": [
#       {
#         "category": "Land vehicle",
#         "confidence": 1
#       },
#       {
#         "category": "Vehicle",
#         "confidence": 1
#       },
#       {
#         "category": "Building",
#         "confidence": 1
#       },
#       {
#         "category": "Car",
#         "confidence": 1
#       }
#     ],
#     "objects": [
#       {
#         "attributes": [
#           "Occluded",
#           "Truncated"
#         ],
#         "bounding_box": {
#           "xmax": "0.4328",
#           "xmin": "0.0000",
#           "ymax": "0.7417",
#           "ymin": "0.0000"
#         },
#         "category": "/m/0cgh4",
#         "text": "Building"
#       },
#       {
#         "attributes": [
#           "Occluded"
#         ],
#         "bounding_box": {
#           "xmax": "0.5344",
#           "xmin": "0.3859",
#           "ymax": "0.5854",
#           "ymin": "0.3198"
#         },
#         "category": "/m/0cgh4",
#         "text": "Building"
#       },
#       {
#         "attributes": [
#           "Occluded",
#           "Truncated"
#         ],
#         "bounding_box": {
#           "xmax": "0.9992",
#           "xmin": "0.7156",
#           "ymax": "0.5417",
#           "ymin": "0.3927"
#         },
#         "category": "/m/0cgh4",
#         "text": "Building (Group)"
#       },
#       {
#         "attributes": [
#           "Occluded"
#         ],
#         "bounding_box": {
#           "xmax": "0.7766",
#           "xmin": "0.6977",
#           "ymax": "0.6271",
#           "ymin": "0.5188"
#         },
#         "category": "/m/0k4j",
#         "text": "Car"
#       },
#       {
#         "attributes": [],
#         "bounding_box": {
#           "xmax": "0.9148",
#           "xmin": "0.7023",
#           "ymax": "0.7688",
#           "ymin": "0.5604"
#         },
#         "category": "/m/0k4j",
#         "text": "Car"
#       },
#       {
#         "attributes": [
#           "Occluded"
#         ],
#         "bounding_box": {
#           "xmax": "0.9367",
#           "xmin": "0.7977",
#           "ymax": "0.6562",
#           "ymin": "0.5437"
#         },
#         "category": "/m/0k4j",
#         "text": "Car"
#       },
#       {
#         "attributes": [
#           "Truncated"
#         ],
#         "bounding_box": {
#           "xmax": "0.9992",
#           "xmin": "0.9344",
#           "ymax": "0.6146",
#           "ymin": "0.5333"
#         },
#         "category": "/m/0k4j",
#         "text": "Car"
#       }
#     ]
#   },
#   "ff5bcca527922108": {
#     "image": {
#       "footnote": "Source URL: <a href='https://c1.staticflickr.com/8/7069/6927706093_1da7481455_o.jpg' target='_blank'>Full Resolution</a>, <a href='https://c8.staticflickr.com/8/7069/6927706093_93115a14c7_z.jpg' target='_blank'>Thumbnail</a>",
#       "footnote_bottom_right": "Author: <a href='https://www.flickr.com/people/emco/' target='_blank'>Emery Graham </a>(<a href='https://creativecommons.org/licenses/by/2.0/' target='_blank'>License</a>)",
#       "footnote_top_right": "Title: P1012074",
#       "rotation": 0.0,
#       "url": "https://c8.staticflickr.com/8/7069/6927706093_93115a14c7_z.jpg",
#       "url_full_res": "https://c1.staticflickr.com/8/7069/6927706093_1da7481455_o.jpg"
#     },
#     "image_labels": [
#       {
#         "category": "Person",
#         "confidence": 1
#       },
#       {
#         "category": "Land vehicle",
#         "confidence": 1
#       },
#       {
#         "category": "Woman",
#         "confidence": 0
#       },
#       {
#         "category": "Man",
#         "confidence": 1
#       },
#       {
#         "category": "Vehicle",
#         "confidence": 1
#       },
#       {
#         "category": "Wheel",
#         "confidence": 1
#       },
#       {
#         "category": "Clothing",
#         "confidence": 1
#       },
#       {
#         "category": "Car",
#         "confidence": 1
#       }
#     ],
#     "objects": [
#       {
#         "attributes": [
#           "Occluded"
#         ],
#         "bounding_box": {
#           "xmax": "0.9144",
#           "xmin": "0.7569",
#           "ymax": "0.8317",
#           "ymin": "0.3650"
#         },
#         "category": "/m/04yx4",
#         "text": "Man"
#       },
#       {
#         "attributes": [],
#         "bounding_box": {
#           "xmax": "0.6444",
#           "xmin": "0.5437",
#           "ymax": "0.7100",
#           "ymin": "0.3892"
#         },
#         "category": "/m/09j2d",
#         "text": "Clothing"
#       },
#       {
#         "attributes": [],
#         "bounding_box": {
#           "xmax": "0.1762",
#           "xmin": "0.0056",
#           "ymax": "0.8908",
#           "ymin": "0.3917"
#         },
#         "category": "/m/0k4j",
#         "text": "Car"
#       },
#       {
#         "attributes": [
#           "Occluded"
#         ],
#         "bounding_box": {
#           "xmax": "0.6919",
#           "xmin": "0.5281",
#           "ymax": "0.8933",
#           "ymin": "0.3650"
#         },
#         "category": "/m/04yx4",
#         "text": "Man"
#       },
#       {
#         "attributes": [
#           "Occluded"
#         ],
#         "bounding_box": {
#           "xmax": "0.6931",
#           "xmin": "0.6250",
#           "ymax": "0.5750",
#           "ymin": "0.3442"
#         },
#         "category": "/m/04yx4",
#         "text": "Man"
#       },
#       {
#         "attributes": [
#           "Occluded"
#         ],
#         "bounding_box": {
#           "xmax": "0.8056",
#           "xmin": "0.7013",
#           "ymax": "0.5908",
#           "ymin": "0.3700"
#         },
#         "category": "/m/04yx4",
#         "text": "Man"
#       },
#       {
#         "attributes": [
#           "Occluded"
#         ],
#         "bounding_box": {
#           "xmax": "0.1831",
#           "xmin": "0.1156",
#           "ymax": "0.8683",
#           "ymin": "0.7617"
#         },
#         "category": "/m/083wq",
#         "text": "Wheel"
#       },
#       {
#         "attributes": [
#           "Occluded"
#         ],
#         "bounding_box": {
#           "xmax": "0.2500",
#           "xmin": "0.1831",
#           "ymax": "0.7908",
#           "ymin": "0.6408"
#         },
#         "category": "/m/083wq",
#         "text": "Wheel"
#       },
#       {
#         "attributes": [
#           "Occluded"
#         ],
#         "bounding_box": {
#           "xmax": "0.4788",
#           "xmin": "0.3650",
#           "ymax": "0.8567",
#           "ymin": "0.6908"
#         },
#         "category": "/m/083wq",
#         "text": "Wheel"
#       },
#       {
#         "attributes": [
#           "Occluded"
#         ],
#         "bounding_box": {
#           "xmax": "0.7150",
#           "xmin": "0.6450",
#           "ymax": "0.8183",
#           "ymin": "0.7517"
#         },
#         "category": "/m/083wq",
#         "text": "Wheel"
#       },
#       {
#         "attributes": [
#           "Occluded"
#         ],
#         "bounding_box": {
#           "xmax": "0.9369",
#           "xmin": "0.8675",
#           "ymax": "0.7908",
#           "ymin": "0.6700"
#         },
#         "category": "/m/083wq",
#         "text": "Wheel"
#       },
#       {
#         "attributes": [],
#         "bounding_box": {
#           "xmax": "0.6544",
#           "xmin": "0.5537",
#           "ymax": "0.7808",
#           "ymin": "0.6192"
#         },
#         "category": "/m/09j2d",
#         "text": "Clothing"
#       },
#       {
#         "attributes": [],
#         "bounding_box": {
#           "xmax": "0.7050",
#           "xmin": "0.6156",
#           "ymax": "0.5808",
#           "ymin": "0.4125"
#         },
#         "category": "/m/09j2d",
#         "text": "Clothing"
#       },
#       {
#         "attributes": [],
#         "bounding_box": {
#           "xmax": "0.8019",
#           "xmin": "0.7087",
#           "ymax": "0.5600",
#           "ymin": "0.4225"
#         },
#         "category": "/m/09j2d",
#         "text": "Clothing"
#       },
#       {
#         "attributes": [],
#         "bounding_box": {
#           "xmax": "0.8919",
#           "xmin": "0.7175",
#           "ymax": "0.6133",
#           "ymin": "0.4258"
#         },
#         "category": "/m/09j2d",
#         "text": "Clothing"
#       },
#       {
#         "attributes": [],
#         "bounding_box": {
#           "xmax": "0.8869",
#           "xmin": "0.8019",
#           "ymax": "0.8200",
#           "ymin": "0.5933"
#         },
#         "category": "/m/09j2d",
#         "text": "Clothing"
#       },
#       {
#         "attributes": [
#           "Occluded"
#         ],
#         "bounding_box": {
#           "xmax": "0.3525",
#           "xmin": "0.1263",
#           "ymax": "0.6225",
#           "ymin": "0.4533"
#         },
#         "category": "/m/0k4j",
#         "text": "Car"
#       }
#     ]
#   },
#   "ff8f0a244a6807ef": {
#     "image": {
#       "footnote": "Source URL: <a href='https://c8.staticflickr.com/6/5132/5421686868_ba3353d8d4_o.jpg' target='_blank'>Full Resolution</a>, <a href='https://c7.staticflickr.com/6/5132/5421686868_9960f26a01_z.jpg' target='_blank'>Thumbnail</a>",
#       "footnote_bottom_right": "Author: <a href='https://www.flickr.com/people/isafmedia/' target='_blank'>ResoluteSupportMedia </a>(<a href='https://creativecommons.org/licenses/by/2.0/' target='_blank'>License</a>)",
#       "footnote_top_right": "Title: 110206-F-8733W-237",
#       "rotation": 0.0,
#       "url": "https://c7.staticflickr.com/6/5132/5421686868_9960f26a01_z.jpg",
#       "url_full_res": "https://c8.staticflickr.com/6/5132/5421686868_ba3353d8d4_o.jpg"
#     },
#     "image_labels": [
#       {
#         "category": "Horse",
#         "confidence": 0
#       },
#       {
#         "category": "Train",
#         "confidence": 0
#       },
#       {
#         "category": "Land vehicle",
#         "confidence": 1
#       },
#       {
#         "category": "Vehicle",
#         "confidence": 1
#       },
#       {
#         "category": "Car",
#         "confidence": 1
#       }
#     ],
#     "objects": [
#       {
#         "attributes": [],
#         "bounding_box": {
#           "xmax": "0.1978",
#           "xmin": "0.0200",
#           "ymax": "0.7277",
#           "ymin": "0.5692"
#         },
#         "category": "/m/0k4j",
#         "text": "Car"
#       }
#     ]
#   }
# }

# %%
image_urls = {}
map = json.loads(content)
for key_ in list(dict(map).keys()): 
    print(map[key_]["image"]["url_full_res"])
    bounding_boxes = []
    for obj in list(map[key_]["objects"]):
        if obj["text"] == category:
            print(obj["bounding_box"])
            bounding_boxes.append(obj["bounding_box"])
    image_urls[map[key_]["image"]["url_full_res"]] = bounding_boxes
# Out:
# _o.jpg
# {'xmax': '0.7344', 'xmin': '0.2119', 'ymax': '0.9284', 'ymin': '0.1177'}
# https://farm4.staticflickr.com/4104/5015544898_b744b68ef8_o.jpg
# {'xmax': '0.0956', 'xmin': '0.0056', 'ymax': '0.6800', 'ymin': '0.5589'}
# {'xmax': '0.6650', 'xmin': '0.6150', 'ymax': '0.6622', 'ymin': '0.5867'}
# {'xmax': '0.7269', 'xmin': '0.6856', 'ymax': '0.6500', 'ymin': '0.5911'}
# {'xmax': '0.9994', 'xmin': '0.9394', 'ymax': '0.9989', 'ymin': '0.8189'}
# https://c4.staticflickr.com/6/5609/15596749238_448af13725_o.jpg
# https://farm3.staticflickr.com/3400/3266432119_93506272b2_o.jpg
# {'xmax': '0.3694', 'xmin': '0.1406', 'ymax': '0.6800', 'ymin': '0.4408'}
# https://c8.staticflickr.com/4/3874/15017186911_16afd18c95_o.jpg
# {'xmax': '0.1859', 'xmin': '0.0367', 'ymax': '0.3927', 'ymin': '0.2771'}
# {'xmax': '0.6047', 'xmin': '0.2531', 'ymax': '0.6323', 'ymin': '0.3229'}
# {'xmax': '0.5000', 'xmin': '0.4469', 'ymax': '0.2938', 'ymin': '0.2313'}
# {'xmax': '0.9992', 'xmin': '0.9281', 'ymax': '0.4625', 'ymin': '0.3510'}
# https://farm3.staticflickr.com/2714/13207523225_f33b076223_o.jpg
# {'xmax': '0.5369', 'xmin': '0.3525', 'ymax': '0.6633', 'ymin': '0.5425'}
# {'xmax': '0.7906', 'xmin': '0.4869', 'ymax': '0.6167', 'ymin': '0.4408'}
# {'xmax': '0.9994', 'xmin': '0.8250', 'ymax': '0.9142', 'ymin': '0.7642'}
# https://farm6.staticflickr.com/3850/15097373145_8be34b09fa_o.jpg
# {'xmax': '0.0169', 'xmin': '0.0000', 'ymax': '0.5067', 'ymin': '0.4917'}
# {'xmax': '0.0231', 'xmin': '0.0000', 'ymax': '0.5067', 'ymin': '0.4808'}
# {'xmax': '0.0425', 'xmin': '0.0219', 'ymax': '0.5050', 'ymin': '0.4825'}
# {'xmax': '0.1187', 'xmin': '0.0656', 'ymax': '0.5400', 'ymin': '0.4917'}
# {'xmax': '0.1394', 'xmin': '0.1081', 'ymax': '0.5192', 'ymin': '0.4792'}
# {'xmax': '0.2275', 'xmin': '0.1706', 'ymax': '0.5400', 'ymin': '0.4917'}
# {'xmax': '0.8456', 'xmin': '0.7863', 'ymax': '0.5400', 'ymin': '0.5000'}
# https://c1.staticflickr.com/4/3276/2938091585_f4f9f50de3_o.jpg
# {'xmax': '0.1333', 'xmin': '0.0000', 'ymax': '0.7137', 'ymin': '0.5775'}
# {'xmax': '0.2183', 'xmin': '0.1167', 'ymax': '0.6575', 'ymin': '0.5275'}
# {'xmax': '0.8900', 'xmin': '0.1600', 'ymax': '0.8237', 'ymin': '0.4475'}
# {'xmax': '0.4767', 'xmin': '0.1983', 'ymax': '0.6488', 'ymin': '0.5525'}
# {'xmax': '0.9333', 'xmin': '0.6867', 'ymax': '0.6925', 'ymin': '0.4975'}
# {'xmax': '0.9983', 'xmin': '0.9133', 'ymax': '0.9900', 'ymin': '0.7488'}
# https://c3.staticflickr.com/3/2725/4101559457_0e1e77ba48_o.jpg
# {'xmax': '0.5312', 'xmin': '0.0000', 'ymax': '0.9991', 'ymin': '0.2082'}
# {'xmax': '0.6275', 'xmin': '0.4556', 'ymax': '0.7460', 'ymin': '0.3707'}
# https://farm5.staticflickr.com/8651/15782852259_c3bc4bfe2a_o.jpg
# {'xmax': '0.8313', 'xmin': '0.0650', 'ymax': '0.7439', 'ymin': '0.3443'}
# https://farm1.staticflickr.com/5331/8758676015_51da4b9580_o.jpg
# https://c7.staticflickr.com/8/7369/16552048975_e2f6cf4521_o.jpg
# {'xmax': '0.8938', 'xmin': '0.0594', 'ymax': '0.7578', 'ymin': '0.0444'}
# https://c7.staticflickr.com/4/3882/14852294151_1a01b8fd89_o.jpg
# {'xmax': '0.2819', 'xmin': '0.1825', 'ymax': '0.9325', 'ymin': '0.8500'}
# {'xmax': '0.5106', 'xmin': '0.2781', 'ymax': '0.9992', 'ymin': '0.8275'}
# {'xmax': '0.7081', 'xmin': '0.4950', 'ymax': '0.9775', 'ymin': '0.8533'}
# {'xmax': '0.8206', 'xmin': '0.7744', 'ymax': '0.8892', 'ymin': '0.8292'}
# {'xmax': '0.9225', 'xmin': '0.8219', 'ymax': '0.8942', 'ymin': '0.8325'}
# {'xmax': '0.9994', 'xmin': '0.9213', 'ymax': '0.8808', 'ymin': '0.8342'}
# https://c5.staticflickr.com/7/6099/6316474321_b74124d74a_o.jpg
# https://c3.staticflickr.com/8/7375/9936379523_fcd5fccfae_o.jpg
# {'xmax': '0.7400', 'xmin': '0.3619', 'ymax': '0.7420', 'ymin': '0.3762'}
# https://c1.staticflickr.com/9/8464/8123792958_a520e6e696_o.jpg
# {'xmax': '0.8037', 'xmin': '0.3137', 'ymax': '0.8987', 'ymin': '0.5516'}
# https://c6.staticflickr.com/4/3672/10789581005_500c9ea16e_o.jpg
# {'xmax': '0.0294', 'xmin': '0.0000', 'ymax': '0.4491', 'ymin': '0.4099'}
# {'xmax': '0.1512', 'xmin': '0.0000', 'ymax': '0.6576', 'ymin': '0.4512'}
# {'xmax': '0.1381', 'xmin': '0.0419', 'ymax': '0.4461', 'ymin': '0.3656'}
# {'xmax': '0.2662', 'xmin': '0.1244', 'ymax': '0.4904', 'ymin': '0.3978'}
# {'xmax': '0.5138', 'xmin': '0.3187', 'ymax': '0.6183', 'ymin': '0.4350'}
# https://farm8.staticflickr.com/4074/4881163231_71a71e4da2_o.jpg
# {'xmax': '0.9994', 'xmin': '0.7531', 'ymax': '0.9991', 'ymin': '0.7594'}
# https://farm1.staticflickr.com/7096/7200435870_eea89f5118_o.jpg
# {'xmax': '0.9189', 'xmin': '0.1525', 'ymax': '0.9356', 'ymin': '0.6781'}
# https://farm4.staticflickr.com/3331/3583191082_74973d5917_o.jpg
# {'xmax': '0.2944', 'xmin': '0.0000', 'ymax': '0.4992', 'ymin': '0.0000'}
# {'xmax': '0.9519', 'xmin': '0.0631', 'ymax': '0.8183', 'ymin': '0.0258'}
# {'xmax': '0.6469', 'xmin': '0.4313', 'ymax': '0.0833', 'ymin': '0.0000'}
# {'xmax': '0.6844', 'xmin': '0.5950', 'ymax': '0.0300', 'ymin': '0.0000'}
# {'xmax': '0.7163', 'xmin': '0.6519', 'ymax': '0.0300', 'ymin': '0.0000'}
# {'xmax': '0.7388', 'xmin': '0.7113', 'ymax': '0.0333', 'ymin': '0.0000'}
# {'xmax': '0.7619', 'xmin': '0.7344', 'ymax': '0.0283', 'ymin': '0.0000'}
# {'xmax': '0.8056', 'xmin': '0.7525', 'ymax': '0.0300', 'ymin': '0.0000'}
# https://farm4.staticflickr.com/367/18838234508_f1bd10c5c7_o.jpg
# {'xmax': '0.3513', 'xmin': '0.0000', 'ymax': '0.5883', 'ymin': '0.2209'}
# {'xmax': '0.8769', 'xmin': '0.1119', 'ymax': '0.8102', 'ymin': '0.2133'}
# https://c7.staticflickr.com/5/4031/4672966131_40a8d52cbd_o.jpg
# {'xmax': '0.2641', 'xmin': '0.0000', 'ymax': '0.6377', 'ymin': '0.1630'}
# {'xmax': '0.9977', 'xmin': '0.0578', 'ymax': '0.9238', 'ymin': '0.1231'}
# {'xmax': '0.8703', 'xmin': '0.8008', 'ymax': '0.3857', 'ymin': '0.2755'}
# https://c5.staticflickr.com/3/2427/3762171158_06c59401f4_o.jpg
# {'xmax': '0.9994', 'xmin': '0.0000', 'ymax': '0.9992', 'ymin': '0.0000'}
# https://farm1.staticflickr.com/4017/4588769586_3d7c513218_o.jpg
# {'xmax': '0.6825', 'xmin': '0.1212', 'ymax': '0.9118', 'ymin': '0.5582'}
# https://c1.staticflickr.com/8/7082/7034842677_6dcd88ddcf_o.jpg
# {'xmax': '0.1394', 'xmin': '0.0000', 'ymax': '0.7717', 'ymin': '0.6104'}
# {'xmax': '0.2437', 'xmin': '0.1319', 'ymax': '0.7328', 'ymin': '0.6220'}
# {'xmax': '0.4738', 'xmin': '0.3956', 'ymax': '0.6691', 'ymin': '0.5897'}
# {'xmax': '0.5387', 'xmin': '0.4688', 'ymax': '0.6667', 'ymin': '0.5980'}
# {'xmax': '0.6012', 'xmin': '0.5406', 'ymax': '0.6394', 'ymin': '0.5848'}
# {'xmax': '0.7069', 'xmin': '0.6044', 'ymax': '0.7221', 'ymin': '0.6137'}
# {'xmax': '0.7769', 'xmin': '0.6456', 'ymax': '0.7444', 'ymin': '0.6154'}
# {'xmax': '0.7200', 'xmin': '0.6469', 'ymax': '0.6328', 'ymin': '0.5790'}
# {'xmax': '0.7994', 'xmin': '0.7319', 'ymax': '0.5947', 'ymin': '0.5534'}
# {'xmax': '0.8163', 'xmin': '0.7456', 'ymax': '0.6931', 'ymin': '0.5964'}
# {'xmax': '0.8237', 'xmin': '0.7644', 'ymax': '0.6187', 'ymin': '0.5897'}
# {'xmax': '0.9137', 'xmin': '0.7863', 'ymax': '0.7345', 'ymin': '0.6046'}
# {'xmax': '0.8394', 'xmin': '0.7925', 'ymax': '0.5823', 'ymin': '0.5517'}
# {'xmax': '0.8644', 'xmin': '0.8044', 'ymax': '0.6121', 'ymin': '0.5658'}
# {'xmax': '0.9231', 'xmin': '0.8631', 'ymax': '0.6046', 'ymin': '0.5583'}
# {'xmax': '0.9294', 'xmin': '0.8944', 'ymax': '0.5997', 'ymin': '0.5641'}
# {'xmax': '0.9800', 'xmin': '0.9331', 'ymax': '0.5806', 'ymin': '0.5376'}
# https://farm4.staticflickr.com/3761/9940940496_00f66372e6_o.jpg
# {'xmax': '0.9994', 'xmin': '0.9681', 'ymax': '0.1926', 'ymin': '0.1457'}
# https://farm3.staticflickr.com/3007/2604746646_4a0465aab3_o.jpg
# {'xmax': '0.8325', 'xmin': '0.2369', 'ymax': '0.7242', 'ymin': '0.4081'}
# https://farm2.staticflickr.com/6203/6087211483_f1f0081bec_o.jpg
# {'xmax': '0.1531', 'xmin': '0.0000', 'ymax': '0.2175', 'ymin': '0.0000'}
# {'xmax': '0.9806', 'xmin': '0.0000', 'ymax': '0.6450', 'ymin': '0.0000'}
# {'xmax': '0.1956', 'xmin': '0.1425', 'ymax': '0.0608', 'ymin': '0.0025'}
# https://c7.staticflickr.com/8/7024/6784515909_0730abf651_o.jpg
# {'xmax': '0.0619', 'xmin': '0.0000', 'ymax': '0.8608', 'ymin': '0.7425'}
# {'xmax': '0.2294', 'xmin': '0.0450', 'ymax': '0.9192', 'ymin': '0.7408'}
# {'xmax': '0.9994', 'xmin': '0.9363', 'ymax': '0.8283', 'ymin': '0.7267'}
# https://farm3.staticflickr.com/5150/5835469267_79fc68c31f_o.jpg
# {'xmax': '0.8131', 'xmin': '0.4763', 'ymax': '1.0000', 'ymin': '0.7855'}
# {'xmax': '0.0525', 'xmin': '0.0000', 'ymax': '0.9991', 'ymin': '0.7309'}
# {'xmax': '0.4844', 'xmin': '0.4031', 'ymax': '0.8344', 'ymin': '0.7460'}
# https://c7.staticflickr.com/4/3891/15193394671_5caaa5fd20_o.jpg
# {'xmax': '0.6462', 'xmin': '0.1081', 'ymax': '0.9833', 'ymin': '0.4850'}
# https://c4.staticflickr.com/1/194/510614206_dc8e509b1f_o.jpg
# {'xmax': '0.5479', 'xmin': '0.0000', 'ymax': '0.9984', 'ymin': '0.8688'}
# {'xmax': '0.4083', 'xmin': '0.2667', 'ymax': '0.8469', 'ymin': '0.7891'}
# https://c4.staticflickr.com/4/3937/15565603837_4836b829df_o.jpg
# {'xmax': '0.3056', 'xmin': '0.0000', 'ymax': '0.6233', 'ymin': '0.4308'}
# {'xmax': '0.6275', 'xmin': '0.0475', 'ymax': '0.7108', 'ymin': '0.4167'}
# {'xmax': '0.9206', 'xmin': '0.3844', 'ymax': '0.8525', 'ymin': '0.4025'}
# https://farm7.staticflickr.com/3806/8882648589_30d95ba9be_o.jpg
# {'xmax': '0.8650', 'xmin': '0.2069', 'ymax': '0.9055', 'ymin': '0.4616'}
# https://farm7.staticflickr.com/7554/16166375735_a3e4a2d663_o.jpg
# {'xmax': '0.9685', 'xmin': '0.0959', 'ymax': '0.7240', 'ymin': '0.0690'}
# https://farm2.staticflickr.com/7070/6859287763_920cfabc33_o.jpg
# {'xmax': '0.6538', 'xmin': '0.6331', 'ymax': '0.7500', 'ymin': '0.7292'}
# {'xmax': '0.7212', 'xmin': '0.6656', 'ymax': '0.7758', 'ymin': '0.7408'}
# {'xmax': '0.7675', 'xmin': '0.7238', 'ymax': '0.7567', 'ymin': '0.7308'}
# {'xmax': '0.9994', 'xmin': '0.8075', 'ymax': '0.9050', 'ymin': '0.7633'}
# {'xmax': '0.9237', 'xmin': '0.8519', 'ymax': '0.8150', 'ymin': '0.7583'}
# https://farm1.staticflickr.com/3045/2735992388_04230a3bd1_o.jpg
# {'xmax': '0.9994', 'xmin': '0.0069', 'ymax': '0.9050', 'ymin': '0.0400'}
# https://farm5.staticflickr.com/3794/12909956565_8d81485760_o.jpg
# {'xmax': '0.9990', 'xmin': '0.0000', 'ymax': '0.2677', 'ymin': '0.0000'}
# https://c6.staticflickr.com/5/4064/4444048867_d72d7b3e4b_o.jpg
# {'xmax': '0.1200', 'xmin': '0.0606', 'ymax': '0.9522', 'ymin': '0.8621'}
# {'xmax': '0.1825', 'xmin': '0.1200', 'ymax': '0.9831', 'ymin': '0.8640'}
# {'xmax': '0.3463', 'xmin': '0.2437', 'ymax': '0.9991', 'ymin': '0.8677'}
# {'xmax': '0.5375', 'xmin': '0.3237', 'ymax': '0.9991', 'ymin': '0.8293'}
# {'xmax': '0.8387', 'xmin': '0.6244', 'ymax': '0.9991', 'ymin': '0.8236'}
# {'xmax': '0.9994', 'xmin': '0.7400', 'ymax': '0.9991', 'ymin': '0.8218'}
# https://c8.staticflickr.com/8/7210/6978012685_59f7f5777f_o.jpg
# https://farm1.staticflickr.com/2140/2165273567_4c2046fe2d_o.jpg
# {'xmax': '0.2175', 'xmin': '0.1894', 'ymax': '0.7323', 'ymin': '0.6935'}
# {'xmax': '0.2675', 'xmin': '0.1894', 'ymax': '0.9139', 'ymin': '0.8344'}
# {'xmax': '0.2050', 'xmin': '0.1906', 'ymax': '0.6935', 'ymin': '0.6679'}
# {'xmax': '0.3356', 'xmin': '0.2781', 'ymax': '0.7398', 'ymin': '0.7029'}
# {'xmax': '0.4556', 'xmin': '0.3237', 'ymax': '0.9820', 'ymin': '0.8969'}
# {'xmax': '0.4419', 'xmin': '0.4044', 'ymax': '0.7162', 'ymin': '0.6916'}
# {'xmax': '0.4944', 'xmin': '0.4300', 'ymax': '0.7360', 'ymin': '0.7010'}
# {'xmax': '0.5019', 'xmin': '0.4300', 'ymax': '0.7824', 'ymin': '0.7398'}
# {'xmax': '0.6813', 'xmin': '0.6006', 'ymax': '0.7711', 'ymin': '0.7237'}
# {'xmax': '0.8144', 'xmin': '0.6444', 'ymax': '0.9991', 'ymin': '0.9413'}
# {'xmax': '0.8031', 'xmin': '0.6494', 'ymax': '0.9300', 'ymin': '0.8288'}
# {'xmax': '0.9456', 'xmin': '0.8531', 'ymax': '0.7975', 'ymin': '0.7550'}
# https://c1.staticflickr.com/6/5486/11842318724_d58425df69_o.jpg
# https://c7.staticflickr.com/9/8782/17313252978_817a5d99d9_o.jpg
# {'xmax': '0.2531', 'xmin': '0.0000', 'ymax': '0.4925', 'ymin': '0.2556'}
# {'xmax': '0.8875', 'xmin': '0.0931', 'ymax': '0.8318', 'ymin': '0.2838'}
# https://farm2.staticflickr.com/66/172039205_e8ce5562df_o.jpg
# {'xmax': '0.5911', 'xmin': '0.3511', 'ymax': '0.4747', 'ymin': '0.3030'}
# https://farm7.staticflickr.com/2459/3888304311_16e435f4c1_o.jpg
# {'xmax': '0.0820', 'xmin': '0.0000', 'ymax': '0.7865', 'ymin': '0.6730'}
# {'xmax': '0.1758', 'xmin': '0.0596', 'ymax': '0.7570', 'ymin': '0.6436'}
# {'xmax': '0.2432', 'xmin': '0.1602', 'ymax': '0.7334', 'ymin': '0.6495'}
# {'xmax': '0.7129', 'xmin': '0.6914', 'ymax': '0.6318', 'ymin': '0.6024'}
# {'xmax': '0.8340', 'xmin': '0.8086', 'ymax': '0.6613', 'ymin': '0.6200'}
# https://farm8.staticflickr.com/3262/2695318849_1a4a98a8bb_o.jpg
# https://c4.staticflickr.com/5/4105/4978741215_5eec0856c1_o.jpg
# {'xmax': '0.1512', 'xmin': '0.0050', 'ymax': '0.9990', 'ymin': '0.8433'}
# {'xmax': '0.3344', 'xmin': '0.2344', 'ymax': '0.6458', 'ymin': '0.5923'}
# {'xmax': '0.3713', 'xmin': '0.2381', 'ymax': '0.7123', 'ymin': '0.6379'}
# {'xmax': '0.3787', 'xmin': '0.2969', 'ymax': '0.6091', 'ymin': '0.5585'}
# {'xmax': '0.4869', 'xmin': '0.3075', 'ymax': '0.8899', 'ymin': '0.7103'}
# {'xmax': '0.4856', 'xmin': '0.4138', 'ymax': '0.5952', 'ymin': '0.5317'}
# {'xmax': '0.6787', 'xmin': '0.6519', 'ymax': '0.4950', 'ymin': '0.4663'}
# {'xmax': '0.8044', 'xmin': '0.7137', 'ymax': '0.7411', 'ymin': '0.6478'}
# {'xmax': '0.9800', 'xmin': '0.9669', 'ymax': '0.4405', 'ymin': '0.4236'}
# {'xmax': '0.9862', 'xmin': '0.9788', 'ymax': '0.4256', 'ymin': '0.4216'}
# https://farm2.staticflickr.com/76/229692845_ee9947c87d_o.jpg
# {'xmax': '0.9131', 'xmin': '0.6934', 'ymax': '0.8620', 'ymin': '0.6927'}
# {'xmax': '0.1777', 'xmin': '0.0615', 'ymax': '0.6745', 'ymin': '0.6146'}
# {'xmax': '0.4150', 'xmin': '0.2627', 'ymax': '0.7135', 'ymin': '0.6484'}
# {'xmax': '0.7256', 'xmin': '0.5176', 'ymax': '0.8268', 'ymin': '0.6706'}
# https://c3.staticflickr.com/5/4105/5014218243_8dca793bd8_o.jpg
# {'xmax': '0.0431', 'xmin': '0.0000', 'ymax': '0.3258', 'ymin': '0.2483'}
# {'xmax': '0.2988', 'xmin': '0.2019', 'ymax': '0.1583', 'ymin': '0.1183'}
# {'xmax': '0.3219', 'xmin': '0.2781', 'ymax': '0.1392', 'ymin': '0.1067'}
# {'xmax': '0.5981', 'xmin': '0.5506', 'ymax': '0.1567', 'ymin': '0.1233'}
# {'xmax': '0.6406', 'xmin': '0.5944', 'ymax': '0.1533', 'ymin': '0.1150'}
# {'xmax': '0.6719', 'xmin': '0.6512', 'ymax': '0.1492', 'ymin': '0.1183'}
# https://c5.staticflickr.com/4/3741/9533083437_3f6371692d_o.jpg
# {'xmax': '0.0611', 'xmin': '0.0011', 'ymax': '0.4983', 'ymin': '0.4017'}
# https://c2.staticflickr.com/6/5206/5223050188_b0446d1c62_o.jpg
# {'xmax': '0.9831', 'xmin': '0.0325', 'ymax': '0.9792', 'ymin': '0.0000'}
# {'xmax': '0.3881', 'xmin': '0.0000', 'ymax': '0.1150', 'ymin': '0.0000'}
# https://farm6.staticflickr.com/4085/5125123019_729a5ef9d4_o.jpg
# {'xmax': '0.9994', 'xmin': '0.0000', 'ymax': '0.9992', 'ymin': '0.0000'}
# {'xmax': '0.6194', 'xmin': '0.5531', 'ymax': '0.3933', 'ymin': '0.3592'}
# {'xmax': '0.7331', 'xmin': '0.6750', 'ymax': '0.3775', 'ymin': '0.3467'}
# {'xmax': '0.8594', 'xmin': '0.7662', 'ymax': '0.3758', 'ymin': '0.3258'}
# https://c4.staticflickr.com/5/4006/4197883209_cbc777f4f8_o.jpg
# {'xmax': '0.6894', 'xmin': '0.4725', 'ymax': '0.7493', 'ymin': '0.5822'}
# {'xmax': '0.1925', 'xmin': '0.0544', 'ymax': '0.7099', 'ymin': '0.5408'}
# {'xmax': '0.3575', 'xmin': '0.2550', 'ymax': '0.6967', 'ymin': '0.5850'}
# {'xmax': '0.4900', 'xmin': '0.3794', 'ymax': '0.6930', 'ymin': '0.5887'}
# https://farm8.staticflickr.com/3877/15027499351_907ef4d748_o.jpg
# {'xmax': '0.8400', 'xmin': '0.1381', 'ymax': '0.9244', 'ymin': '0.5503'}
# https://c2.staticflickr.com/6/5275/7410371470_63267d3818_o.jpg
# {'xmax': '0.5587', 'xmin': '0.3987', 'ymax': '0.5039', 'ymin': '0.3615'}
# {'xmax': '0.4125', 'xmin': '0.2294', 'ymax': '0.4939', 'ymin': '0.3804'}
# {'xmax': '0.5750', 'xmin': '0.5469', 'ymax': '0.4939', 'ymin': '0.4194'}
# {'xmax': '0.6262', 'xmin': '0.5600', 'ymax': '0.5039', 'ymin': '0.4438'}
# {'xmax': '0.7775', 'xmin': '0.7225', 'ymax': '0.4627', 'ymin': '0.4027'}
# https://farm8.staticflickr.com/7340/13967207058_b9b63e8ded_o.jpg
# {'xmax': '0.4694', 'xmin': '0.0644', 'ymax': '0.7994', 'ymin': '0.4798'}
# {'xmax': '0.3362', 'xmin': '0.1619', 'ymax': '0.5726', 'ymin': '0.4536'}
# {'xmax': '0.6112', 'xmin': '0.2938', 'ymax': '0.6739', 'ymin': '0.3992'}
# {'xmax': '0.9756', 'xmin': '0.4437', 'ymax': '0.9110', 'ymin': '0.4067'}
# {'xmax': '0.9994', 'xmin': '0.9356', 'ymax': '0.7816', 'ymin': '0.4836'}
# https://c7.staticflickr.com/4/3042/2528899062_91980d8c01_o.jpg
# {'xmax': '0.1000', 'xmin': '0.0612', 'ymax': '0.0950', 'ymin': '0.0433'}
# {'xmax': '0.1800', 'xmin': '0.1250', 'ymax': '0.0817', 'ymin': '0.0350'}
# {'xmax': '0.3675', 'xmin': '0.2331', 'ymax': '0.0767', 'ymin': '0.0000'}
# {'xmax': '0.6825', 'xmin': '0.5394', 'ymax': '0.0367', 'ymin': '0.0000'}
# {'xmax': '0.9994', 'xmin': '0.6700', 'ymax': '0.1950', 'ymin': '0.0000'}
# https://c3.staticflickr.com/6/5252/5410264136_360a9d92a6_o.jpg
# {'xmax': '0.9600', 'xmin': '0.0569', 'ymax': '0.8958', 'ymin': '0.1808'}
# {'xmax': '0.9994', 'xmin': '0.7462', 'ymax': '0.5825', 'ymin': '0.2258'}
# https://c5.staticflickr.com/3/2267/2140056862_2370e3e3b3_o.jpg
# {'xmax': '0.5769', 'xmin': '0.3175', 'ymax': '0.9236', 'ymin': '0.7523'}
# https://farm3.staticflickr.com/2950/15198530769_61a765ed60_o.jpg
# {'xmax': '0.0238', 'xmin': '0.0000', 'ymax': '0.4859', 'ymin': '0.4034'}
# {'xmax': '0.0519', 'xmin': '0.0213', 'ymax': '0.4456', 'ymin': '0.4109'}
# {'xmax': '0.8862', 'xmin': '0.8200', 'ymax': '0.4015', 'ymin': '0.3593'}
# {'xmax': '0.8994', 'xmin': '0.8275', 'ymax': '0.4118', 'ymin': '0.3696'}
# {'xmax': '0.9994', 'xmin': '0.8413', 'ymax': '0.6548', 'ymin': '0.3687'}
# {'xmax': '0.9994', 'xmin': '0.9794', 'ymax': '0.4916', 'ymin': '0.4493'}
# https://farm7.staticflickr.com/3875/14754381070_1f0a7445dc_o.jpg
# {'xmax': '0.8694', 'xmin': '0.0181', 'ymax': '0.9868', 'ymin': '0.0000'}
# https://c4.staticflickr.com/4/3604/3552335587_df1be486ed_o.jpg
# {'xmax': '0.1825', 'xmin': '0.0000', 'ymax': '0.9563', 'ymin': '0.8538'}
# {'xmax': '0.4058', 'xmin': '0.3492', 'ymax': '0.8456', 'ymin': '0.8169'}
# {'xmax': '0.4625', 'xmin': '0.4033', 'ymax': '0.8544', 'ymin': '0.8200'}
# {'xmax': '0.5175', 'xmin': '0.4675', 'ymax': '0.8475', 'ymin': '0.8200'}
# {'xmax': '0.7158', 'xmin': '0.6333', 'ymax': '0.8712', 'ymin': '0.8219'}
# {'xmax': '0.7408', 'xmin': '0.6950', 'ymax': '0.8631', 'ymin': '0.8169'}
# {'xmax': '0.9250', 'xmin': '0.8183', 'ymax': '0.8919', 'ymin': '0.8306'}
# https://c6.staticflickr.com/6/5147/5856212595_b2f5ebf875_o.jpg
# {'xmax': '0.4213', 'xmin': '0.3575', 'ymax': '0.7092', 'ymin': '0.6417'}
# {'xmax': '0.8544', 'xmin': '0.6238', 'ymax': '0.8649', 'ymin': '0.6867'}
# {'xmax': '0.9481', 'xmin': '0.8519', 'ymax': '0.6829', 'ymin': '0.6098'}
# {'xmax': '0.9469', 'xmin': '0.9156', 'ymax': '0.6173', 'ymin': '0.5910'}
# {'xmax': '0.9875', 'xmin': '0.9437', 'ymax': '0.6135', 'ymin': '0.5966'}
# https://c6.staticflickr.com/6/5454/9352412299_d707505c31_o.jpg
# {'xmax': '0.8606', 'xmin': '0.0000', 'ymax': '0.9184', 'ymin': '0.0028'}
# https://farm7.staticflickr.com/3408/4630817050_3f53cf2def_o.jpg
# https://farm1.staticflickr.com/3440/3236285947_3cfb9b11df_o.jpg
# {'xmax': '0.2644', 'xmin': '0.0000', 'ymax': '0.9992', 'ymin': '0.6858'}
# {'xmax': '0.2500', 'xmin': '0.0938', 'ymax': '0.7958', 'ymin': '0.7117'}
# {'xmax': '0.8769', 'xmin': '0.5175', 'ymax': '0.8717', 'ymin': '0.6775'}
# https://farm1.staticflickr.com/4076/4890835044_beacf88926_o.jpg
# https://c8.staticflickr.com/8/7484/15744515032_1fdb571d65_o.jpg
# {'xmax': '0.3006', 'xmin': '0.0806', 'ymax': '0.8412', 'ymin': '0.7227'}
# https://c2.staticflickr.com/6/5100/5469996579_e98dc3e971_o.jpg
# {'xmax': '0.3464', 'xmin': '0.0292', 'ymax': '0.8669', 'ymin': '0.7794'}
# {'xmax': '0.4583', 'xmin': '0.1227', 'ymax': '0.8806', 'ymin': '0.7762'}
# https://c7.staticflickr.com/2/1204/1384108011_fc20d37b41_o.jpg
# {'xmax': '0.7766', 'xmin': '0.6977', 'ymax': '0.6271', 'ymin': '0.5188'}
# {'xmax': '0.9148', 'xmin': '0.7023', 'ymax': '0.7688', 'ymin': '0.5604'}
# {'xmax': '0.9367', 'xmin': '0.7977', 'ymax': '0.6562', 'ymin': '0.5437'}
# {'xmax': '0.9992', 'xmin': '0.9344', 'ymax': '0.6146', 'ymin': '0.5333'}
# https://c1.staticflickr.com/8/7069/6927706093_1da7481455_o.jpg
# {'xmax': '0.1762', 'xmin': '0.0056', 'ymax': '0.8908', 'ymin': '0.3917'}
# {'xmax': '0.3525', 'xmin': '0.1263', 'ymax': '0.6225', 'ymin': '0.4533'}
# https://c8.staticflickr.com/6/5132/5421686868_ba3353d8d4_o.jpg
# {'xmax': '0.1978', 'xmin': '0.0200', 'ymax': '0.7277', 'ymin': '0.5692'}

# %%
image_urls[list(image_urls.keys())[1]]
# Out:
# [{'xmax': '0.2310', 'xmin': '0.0000', 'ymax': '0.6447', 'ymin': '0.3748'},
#  {'xmax': '0.5780', 'xmin': '0.0130', 'ymax': '0.7436', 'ymin': '0.2579'},
#  {'xmax': '0.9810', 'xmin': '0.4460', 'ymax': '0.8861', 'ymin': '0.3298'},
#  {'xmax': '0.9550', 'xmin': '0.9370', 'ymax': '0.5922', 'ymin': '0.4918'}]

# %%
original_images = list(image_urls.keys())
num_of_images = len(original_images)

info("Downloading images...")
print("[", end="")

# create directory if not exists
if not os.path.exists(f"{dest}/{category}"):
    os.mkdir(f"{dest}/{category}")

# download images
for i, img in enumerate(original_images):
    if i % 15 == 0:
        # print(i)
        print("=", end="")
        sys.stdout.flush()
    # if i == 100:
    #     break

    # print(f"Getting {i}. image")
    r = requests.get(img)
    f = open(f"{args.dest}/{args.category}/{time.time()}.jpg", "wb")
    f.write(r.content)
    f.close()
print("]")
info("Finished downloading images")
# Out:
# [INFO] Downloading images...
# []
# [INFO] Finished downloading images

# %%
content
# Out:
# ['[',
#  '  "/m/083wq", ',
#  '  "/m/0h9mv", ',
#  '  "/m/0d4v4", ',
#  '  "/m/01g317", ',
#  '  "/m/07j7r", ',
#  '  "/m/04yx4", ',
#  '  "/m/09j2d", ',
#  '  "/m/09j5n", ',
#  '  "/m/0cgh4", ',
#  '  "/m/03jm5", ',
#  '  "/m/03bt1vf", ',
#  '  "/m/0dzct", ',
#  '  "/m/05s2s", ',
#  '  "/m/01jfm_", ',
#  '  "/m/08dz3q", ',
#  '  "/m/033rq4", ',
#  '  "/m/07r04", ',
#  '  "/m/01bqk0", ',
#  '  "/m/01bjv", ',
#  '  "/m/0fly7", ',
#  '  "/m/03q69", ',
#  '  "/m/0pg52", ',
#  '  "/m/04rky", ',
#  '  "/m/0199g", ',
#  '  "/m/04_sv", ',
#  '  "/m/05r655", ',
#  '  "/m/079cl", ',
#  '  "/m/0c9ph5", ',
#  '  "/m/0dzf4", ',
#  '  "/m/0138tl", ',
#  '  "/m/015qff", ',
#  '  "/m/02p0tk3", ',
#  '  "/m/04hgtk", ',
#  '  "/m/0cdl1", ',
#  '  "/m/035r7c", ',
#  '  "/m/01knjb", ',
#  '  "/m/01mqdt", ',
#  '  "/m/01fdzj", ',
#  '  "/m/01bl7v", ',
#  '  "/m/0463sg", ',
#  '  "/m/017ftj", ',
#  '  "/m/01xyhv", ',
#  '  "/m/0zvk5", ',
#  '  "/m/0jyfg", ',
#  '  "/m/032b3c", ',
#  '  "/m/02dgv", ',
#  '  "/m/0k65p", ',
#  '  "/m/01mzpv", ',
#  '  "/m/03120", ',
#  '  "/m/019jd", ',
#  '  "/m/01d40f", ',
#  '  "/m/03p3bw", ',
#  '  "/m/01bfm9", ',
#  '  "/m/014sv8", ',
#  '  "/m/0k0pj", ',
#  '  "/m/0bt9lr", ',
#  '  "/m/01n5jq", ',
#  '  "/m/01j61q", ',
#  '  "/m/0283dt1", ',
#  '  "/m/054_l", ',
#  '  "/m/0hnnb", ',
#  '  "/m/04bcr3", ',
#  '  "/m/03fp41", ',
#  '  "/m/07jdr", ',
#  '  "/m/07mhn", ',
#  '  "/m/0c_jw", ',
#  '  "/m/0fm3zh", ',
#  '  "/m/015p6", ',
#  '  "/m/03k3r", ',
#  '  "/m/06msq", ',
#  '  "/m/02_n6y", ',
#  '  "/m/018p4k", ',
#  '  "/m/05y5lj", ',
#  '  "/m/0cmf2", ',
#  '  "/m/02dl1y", ',
#  '  "/m/0bjyj5", ',
#  '  "/m/0dkzw", ',
#  '  "/m/01j51", ',
#  '  "/m/0cvnqh", ',
#  '  "/m/01ww8y", ',
#  '  "/m/02wbm", ',
#  '  "/m/0jbk", ',
#  '  "/m/01_bhs", ',
#  '  "/m/01xygc", ',
#  '  "/m/0bt_c3", ',
#  '  "/m/04m6gz", ',
#  '  "/m/01xq0k1", ',
#  '  "/m/0h8mhzd", ',
#  '  "/m/039xj_", ',
#  '  "/m/0323sq", ',
#  '  "/m/0270h", ',
#  '  "/m/04dr76w", ',
#  '  "/m/0271t", ',
#  '  "/m/02wbtzl", ',
#  '  "/m/02xwb", ',
#  '  "/m/0dv77", ',
#  '  "/m/0gjbg72", ',
#  '  "/m/01yrx", ',
#  '  "/m/052lwg6", ',
#  '  "/m/01gkx_", ',
#  '  "/m/01lynh", ',
#  '  "/m/04szw", ',
#  '  "/m/026t6", ',
#  '  "/m/0hf58v5", ',
#  '  "/m/0cffdh", ',
#  '  "/m/02fq_6", ',
#  '  "/m/01rzcn", ',
#  '  "/m/0f4s2w", ',
#  '  "/m/06k2mb", ',
#  '  "/m/0k5j", ',
#  '  "/m/0dbvp", ',
#  '  "/m/025nd", ',
#  '  "/m/06_fw", ',
#  '  "/m/018xm", ',
#  '  "/m/0220r2", ',
#  '  "/m/06m11", ',
#  '  "/m/0268lbt", ',
#  '  "/m/07c52", ',
#  '  "/m/01n4qj", ',
#  '  "/m/0167gd", ',
#  '  "/m/025dyy", ',
#  '  "/m/06z37_", ',
#  '  "/m/0dv5r", ',
#  '  "/m/025rp__", ',
#  '  "/m/050k8", ',
#  '  "/m/05zsy", ',
#  '  "/m/02p3w7d", ',
#  '  "/m/01b638", ',
#  '  "/m/012n7d", ',
#  '  "/m/01lrl", ',
#  '  "/m/01jfsr", ',
#  '  "/m/0342h", ',
#  '  "/m/015h_t", ',
#  '  "/m/083kb", ',
#  '  "/m/01599", ',
#  '  "/m/09ct_", ',
#  '  "/m/09ddx", ',
#  '  "/m/07cmd", ',
#  '  "/m/01226z", ',
#  '  "/m/02pv19", ',
#  '  "/m/015qbp", ',
#  '  "/m/0d5gx", ',
#  '  "/m/078n6m", ',
#  '  "/m/04brg2", ',
#  '  "/m/01rkbr", ',
#  '  "/m/06c54", ',
#  '  "/m/0ftb8", ',
#  '  "/m/03c7gz", ',
#  '  "/m/02wv6h6", ',
#  '  "/m/07qxg_", ',
#  '  "/m/0qmmr", ',
#  '  "/m/04vv5k", ',
#  '  "/m/05gqfk", ',
#  '  "/m/01x3z", ',
#  '  "/m/01cmb2", ',
#  '  "/m/080hkjn", ',
#  '  "/m/0dftk", ',
#  '  "/m/0dbzx", ',
#  '  "/m/02h19r", ',
#  '  "/m/03nfch", ',
#  '  "/m/076bq", ',
#  '  "/m/0cnyhnx", ',
#  '  "/m/07k1x", ',
#  '  "/m/014y4n", ',
#  '  "/m/020kz", ',
#  '  "/m/0bwd_0j", ',
#  '  "/m/01c648", ',
#  '  "/m/0fqt361", ',
#  '  "/m/01s55n", ',
#  '  "/m/01pns0", ',
#  '  "/m/073bxn", ',
#  '  "/m/081qc", ',
#  '  "/m/0gd2v", ',
#  '  "/m/0ph39", ',
#  '  "/m/09kx5", ',
#  '  "/m/02522", ',
#  '  "/m/054xkw", ',
#  '  "/m/07cx4", ',
#  '  "/m/0kmg4", ',
#  '  "/m/02crq1", ',
#  '  "/m/01yx86", ',
#  '  "/m/012w5l", ',
#  '  "/m/02lbcq", ',
#  '  "/m/07pj7bq", ',
#  '  "/m/0gv1x", ',
#  '  "/m/0ch_cf", ',
#  '  "/m/0gjkl", ',
#  '  "/m/03fwl", ',
#  '  "/m/03__z0", ',
#  '  "/m/04h7h", ',
#  '  "/m/07bgp", ',
#  '  "/m/019w40", ',
#  '  "/m/071p9", ',
#  '  "/m/01x_v", ',
#  '  "/m/08pbxl", ',
#  '  "/m/021mn", ',
#  '  "/m/0jly1", ',
#  '  "/m/01gmv2", ',
#  '  "/m/02zn6n", ',
#  '  "/m/02hj4", ',
#  '  "/m/0cxn2", ',
#  '  "/m/084zz", ',
#  '  "/m/029tx", ',
#  '  "/m/01x3jk", ',
#  '  "/m/02p5f1q", ',
#  '  "/m/096mb", ',
#  '  "/m/07dm6", ',
#  '  "/m/0crjs", ',
#  '  "/m/01btn", ',
#  '  "/m/01y9k5", ',
#  '  "/m/0djtd", ',
#  '  "/m/07gql", ',
#  '  "/m/0h8n5zk", ',
#  '  "/m/016m2d", ',
#  '  "/m/05441v", ',
#  '  "/m/03m3pdh", ',
#  '  "/m/09rvcxw", ',
#  '  "/m/03rszm", ',
#  '  "/m/09tvcd", ',
#  '  "/m/0hg7b", ',
#  '  "/m/02vqfm", ',
#  '  "/m/0b_rs", ',
#  '  "/m/031n1", ',
#  '  "/m/0cdn1", ',
#  '  "/m/01xqw", ',
#  '  "/m/0h99cwc", ',
#  '  "/m/01940j", ',
#  '  "/m/01_5g", ',
#  '  "/m/01fb_0", ',
#  '  "/m/04ylt", ',
#  '  "/m/07y_7", ',
#  '  "/m/0fszt", ',
#  '  "/m/057cc", ',
#  '  "/m/0ccs93", ',
#  '  "/m/0284d", ',
#  '  "/m/02jnhm", ',
#  '  "/m/01m2v", ',
#  '  "/m/03bj1", ',
#  '  "/m/050gv4", ',
#  '  "/m/0by6g", ',
#  '  "/m/0cyhj_", ',
#  '  "/m/02wmf", ',
#  '  "/m/07c6l", ',
#  '  "/m/06ncr", ',
#  '  "/m/0174n1", ',
#  '  "/m/01s105", ',
#  '  "/m/01b9xk", ',
#  '  "/m/046dlr", ',
#  '  "/m/0jqgx", ',
#  '  "/m/071qp", ',
#  '  "/m/024g6", ',
#  '  "/m/01z1kdw", ',
#  '  "/m/03vt0", ',
#  '  "/m/03ssj5", ',
#  '  "/m/0d4w1", ',
#  '  "/m/05z6w", ',
#  '  "/m/05n4y", ',
#  '  "/m/0174k2", ',
#  '  "/m/02rdsp", ',
#  '  "/m/014trl", ',
#  '  "/m/031b6r", ',
#  '  "/m/05r5c", ',
#  '  "/m/0h8l4fh", ',
#  '  "/m/0jy4k", ',
#  '  "/m/0898b", ',
#  '  "/m/02x984l", ',
#  '  "/m/068zj", ',
#  '  "/m/0663v", ',
#  '  "/m/0cyfs", ',
#  '  "/m/0633h", ',
#  '  "/m/0f6nr", ',
#  '  "/m/06nrc", ',
#  '  "/m/01llwg", ',
#  '  "/m/04kkgm", ',
#  '  "/m/03hj559", ',
#  '  "/m/06c7f7", ',
#  '  "/m/02zvsm", ',
#  '  "/m/0l515", ',
#  '  "/m/03q5c7", ',
#  '  "/m/03grzl", ',
#  '  "/m/026qbn5", ',
#  '  "/m/0dtln", ',
#  '  "/m/02pkr5", ',
#  '  "/m/02ctlc", ',
#  '  "/m/0h8my_4", ',
#  '  "/m/04p0qw", ',
#  '  "/m/01kb5b", ',
#  '  "/m/09b5t", ',
#  '  "/m/02s195", ',
#  '  "/m/0bh9flk", ',
#  '  "/m/0f6wt", ',
#  '  "/m/020jm", ',
#  '  "/m/05kms", ',
#  '  "/m/0176mf", ',
#  '  "/m/0c29q", ',
#  '  "/m/07fbm7", ',
#  '  "/m/01f91_", ',
#  '  "/m/09kmb", ',
#  '  "/m/03fj2", ',
#  '  "/m/04ctx", ',
#  '  "/m/09dzg", ',
#  '  "/m/047j0r", ',
#  '  "/m/0306r", ',
#  '  "/m/02jz0l", ',
#  '  "/m/0cd4d", ',
#  '  "/m/057p5t", ',
#  '  "/m/01b7fy", ',
#  '  "/m/03g8mr", ',
#  '  "/m/09g1w", ',
#  '  "/m/06nwz", ',
#  '  "/m/0d8zb", ',
#  '  "/m/0f9_l", ',
#  '  "/m/09d5_", ',
#  '  "/m/09qck", ',
#  '  "/m/02y6n", ',
#  '  "/m/04gth", ',
#  '  "/m/04c0y", ',
#  '  "/m/021sj1", ',
#  '  "/m/01tcjp", ',
#  '  "/m/0pcr", ',
#  '  "/m/0642b4", ',
#  '  "/m/07clx", ',
#  '  "/m/05kyg_", ',
#  '  "/m/0h8mzrc", ',
#  '  "/m/099ssp", ',
#  '  "/m/014j1m", ',
#  '  "/m/01dxs", ',
#  '  "/m/07crc", ',
#  '  "/m/09728", ',
#  '  "/m/06y5r", ',
#  '  "/m/0mcx2", ',
#  '  "/m/05ctyq", ',
#  '  "/m/04yqq2", ',
#  '  "/m/0l14j_", ',
#  '  "/m/084rd", ',
#  '  "/m/06__v", ',
#  '  "/m/033cnk", ',
#  '  "/m/01hrv5", ',
#  '  "/m/06mf6", ',
#  '  "/m/0p833", ',
#  '  "/m/0703r8", ',
#  '  "/m/02jfl0", ',
#  '  "/m/024d2", ',
#  '  "/m/061_f", ',
#  '  "/m/0fqfqc", ',
#  '  "/m/0h8n6f9", ',
#  '  "/m/09csl", ',
#  '  "/m/03d443", ',
#  '  "/m/02jvh9", ',
#  '  "/m/0ft9s", ',
#  '  "/m/09f_2", ',
#  '  "/m/0jwn_", ',
#  '  "/m/02zt3", ',
#  '  "/m/012074", ',
#  '  "/m/01dwwc", ',
#  '  "/m/01xs3r", ',
#  '  "/m/03dnzn", ',
#  '  "/m/04lvq_", ',
#  '  "/m/02x8cch", ',
#  '  "/m/02gzp", ',
#  '  "/m/01432t", ',
#  '  "/m/04zwwv", ',
#  '  "/m/07j87", ',
#  '  "/m/044r5d", ',
#  '  "/m/01h44", ',
#  '  "/m/0_dqb", ',
#  '  "/m/01k6s3", ',
#  '  "/m/015wgc", ',
#  '  "/m/0_cp5", ',
#  '  "/m/06pcq", ',
#  '  "/m/0152hh", ',
#  '  "/m/0k1tl", ',
#  '  "/m/01gllr", ',
#  '  "/m/03wym", ',
#  '  "/m/052sf", ',
#  '  "/m/011k07", ',
#  '  "/m/0c2jj", ',
#  '  "/m/03qjg", ',
#  '  "/m/0fbdv", ',
#  '  "/m/058qzx", ',
#  '  "/m/02xqq", ',
#  '  "/m/07xyvk", ',
#  '  "/m/0dq75", ',
#  '  "/m/04m9y", ',
#  '  "/m/05w9t9", ',
#  '  "/m/076lb9", ',
#  '  "/m/04z4wx", ',
#  '  "/m/0dv9c", ',
#  '  "/m/02vkqh8", ',
#  '  "/m/065h6l", ',
#  '  "/m/061hd_", ',
#  '  "/m/015x4r", ',
#  '  "/m/01lcw4", ',
#  '  "/m/0c06p", ',
#  '  "/m/01nq26", ',
#  '  "/m/0584n8", ',
#  '  "/m/0ll1f78", ',
#  '  "/m/06l9r", ',
#  '  "/m/063rgb", ',
#  '  "/m/0h2r6", ',
#  '  "/m/0cl4p", ',
#  '  "/m/02wg_p", ',
#  '  "/m/01j4z9", ',
#  '  "/m/01h8tj", ',
#  '  "/m/0ct4f", ',
#  '  "/m/0km7z", ',
#  '  "/m/05bm6", ',
#  '  "/m/015x5n", ',
#  '  "/m/03qrc", ',
#  '  "/m/02ddwp", ',
#  '  "/m/09ld4", ',
#  '  "/m/0nl46", ',
#  '  "/m/03bbps", ',
#  '  "/m/0hkxq", ',
#  '  "/m/02d9qx", ',
#  '  "/m/0d20w4", ',
#  '  "/m/0cjs7", ',
#  '  "/m/09gys", ',
#  '  "/m/0175cv", ',
#  '  "/m/04y4h8h", ',
#  '  "/m/0gm28", ',
#  '  "/m/02wv84t", ',
#  '  "/m/03hl4l9", ',
#  '  "/m/020lf", ',
#  '  "/m/0755b", ',
#  '  "/m/02fh7f", ',
#  '  "/m/01krhy", ',
#  '  "/m/0lt4_", ',
#  '  "/m/02tsc9", ',
#  '  "/m/01vbnl", ',
#  '  "/m/029bxz", ',
#  '  "/m/02mqfb", ',
#  '  "/m/03ldnb", ',
#  '  "/m/01m4t", ',
#  '  "/m/07yv9", ',
#  '  "/m/03m3vtv", ',
#  '  "/m/0l3ms", ',
#  '  "/m/0kpqd", ',
#  '  "/m/0dt3t", ',
#  '  "/m/0fz0h", ',
#  '  "/m/0c3mkw", ',
#  '  "/m/04rmv", ',
#  '  "/m/0mw_6", ',
#  '  "/m/0388q", ',
#  '  "/m/040b_t", ',
#  '  "/m/012ysf", ',
#  '  "/m/02pdsw", ',
#  '  "/m/0nybt", ',
#  '  "/m/0cyf8", ',
#  '  "/m/02bm9n", ',
#  '  "/m/0cn6p", ',
#  '  "/m/04v6l4", ',
#  '  "/m/02pjr4", ',
#  '  "/m/03qhv5", ',
#  '  "/m/09k_b", ',
#  '  "/m/01r546", ',
#  '  "/m/05676x", ',
#  '  "/m/03wvsk", ',
#  '  "/m/0fldg", ',
#  '  "/m/03jbxj", ',
#  '  "/m/03kt2w", ',
#  '  "/m/04tn4x", ',
#  '  "/m/02cvgx", ',
#  '  "/m/027pcv", ',
#  '  "/m/0cmx8", ',
#  '  "/m/0czz2", ',
#  '  "/m/0162_1", ',
#  '  "/m/080n7g", ',
#  '  "/m/01h3n", ',
#  '  "/m/03q5t", ',
#  '  "/m/02l8p9", ',
#  '  "/m/0fx9l", ',
#  '  "/m/054fyh", ',
#  '  "/m/05z55", ',
#  '  "/m/034c16", ',
#  '  "/m/02z51p", ',
#  '  "/m/01g3x7", ',
#  '  "/m/0cjq5", ',
#  '  "/m/0gxl3", ',
#  '  "/m/01lsmm", ',
#  '  "/m/02g30s", ',
#  '  "/m/01dwsz", ',
#  '  "/m/0h8jyh6", ',
#  '  "/m/03xxp", ',
#  '  "/m/0h8n6ft", ',
#  '  "/m/0130jx", ',
#  '  "/m/035vxb", ',
#  '  "/m/043nyj", ',
#  '  "/m/0h8nsvg", ',
#  '  "/m/07030", ',
#  '  "/m/084hf", ',
#  '  "/m/0319l", ',
#  '  "/m/0wdt60w", ',
#  '  "/m/0h8nr_l", ',
#  '  "/m/0hdln", ',
#  '  "/m/03tw93", ',
#  '  "/m/01d380", ',
#  '  "/m/0440zs", ',
#  '  "/m/025fsf", ',
#  '  "/m/073g6", ',
#  '  "/m/02068x", ',
#  '  "/m/0gj37", ',
#  '  "/m/0h8ntjv", ',
#  '  "/m/01dws", ',
#  '  "/m/0mkg", ',
#  '  "/m/0h8n27j", ',
#  '  "/m/0xzly", ',
#  '  "/m/029b3", ',
#  '  "/m/01j3zr", ',
#  '  "/m/02f9f_", ',
#  '  "/m/08p92x", ',
#  '  "/m/0242l", ',
#  '  "/m/01f8m5", ',
#  '  "/m/01j5ks", ',
#  '  "/m/07v9_z", ',
#  '  "/m/047v4b", ',
#  '  "/m/02vwcm", ',
#  '  "/m/0dj6p", ',
#  '  "/m/08ks85", ',
#  '  "/m/0h8kx63", ',
#  '  "/m/0f571", ',
#  '  "/m/03v5tg", ',
#  '  "/m/0hnyx", ',
#  '  "/m/06_72j", ',
#  '  "/m/0jg57", ',
#  '  "/m/0fp6w", ',
#  '  "/m/06j2d", ',
#  '  "/m/013y1f", ',
#  '  "/m/0cqn2", ',
#  '  "/m/04169hn", ',
#  '  "/m/0m53l", ',
#  '  "/m/0_k2", ',
#  '  "/m/09f20", ',
#  '  "/m/0d_2m", ',
#  '  "/m/06bt6", ',
#  '  "/m/01bms0", ',
#  '  "/m/07dd4", ',
#  '  "/m/019h78", ',
#  '  "/m/078jl", ',
#  '  "/m/0420v5", ',
#  '  "/m/04f5ws", ',
#  '  "/m/09gtd", ',
#  '  "/m/03s_tn", ',
#  '  "/m/0cydv", ',
#  '  "/m/0ky7b", ',
#  '  "/m/0gd36", ',
#  '  "/m/03bk1", ',
#  '  "/m/03m5k", ',
#  '  "/m/0fbw6", ',
#  '  "/m/0h8lkj8", ',
#  '  "/m/01fh4r", ',
#  '  "/m/04h8sr", ',
#  '  "/m/0449p", ',
#  '  "/m/0h23m", ',
#  '  "/m/0grw1", ',
#  '  "/m/03txqz", ',
#  '  "/m/0xfy", ',
#  '  "/m/02d1br", ',
#  '  "/m/0b3fp9", ',
#  '  "/m/05vtc", ',
#  '  "/m/01prls", ',
#  '  "/m/074d1", ',
#  '  "/m/04zpv", ',
#  '  "/m/0c568", ',
#  '  "/m/03l9g", ',
#  '  "/m/01xgg_", ',
#  '  "/m/019dx1", ',
#  '  "/m/02w3r3", ',
#  '  "/m/0h8nm9j", ',
#  '  "/m/02xb7qb", ',
#  '  "/m/0frqm", ',
#  '  "/m/0c3m8g", ',
#  '  "/m/08hvt4", ',
#  '  "/m/0f8s22", ',
#  '  "/m/04g2r", ',
#  '  "/m/01nkt", ',
#  '  "/m/027rl48", ',
#  '  "/m/0n28_", ',
#  '  "/m/0j496", ',
#  '  "/m/02rgn06", ',
#  '  "/m/0fj52s", ',
#  '  "/m/0qjjc", ',
#  '  "/m/0llzx", ',
#  '  "/m/05_5p_0", ',
#  '  "/m/01dy8n", ',
#  '  "/m/0hqkz", ',
#  '  "/m/030610", ',
#  '  "/m/07mcwg", ',
#  '  "/m/07kng9", ',
#  '  "/m/012xff", ',
#  '  "/m/03hlz0c", ',
#  '  "/m/04cp_", ',
#  '  "/m/0120dh", ',
#  '  "/m/0kpt_", ',
#  '  "/m/018j2", ',
#  '  "/m/0271qf7", ',
#  '  "/m/02w3_ws", ',
#  '  "/m/03y6mg"',
#  ']']
